# %% [markdown]
# # SSD300 Training Tutorial
#
# This tutorial explains how to train an SSD300 on the Pascal VOC datasets. The preset parameters reproduce the training of the original SSD300 "07+12" model. Training SSD512 works simiarly, so there's no extra tutorial for that. The same goes for training on other datasets.
#
# You can find a summary of a full training here to get an impression of what it should look like:
# [SSD300 "07+12" training summary](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/ssd_keras
# !ls

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 0. Preliminary note
#
# All places in the code where you need to make any changes are marked `TODO` and explained accordingly. All code cells that don't contain `TODO` markers just need to be executed.

# %% [markdown]
# ## 1. Set the model configuration parameters
#
# This section sets the configuration parameters for the model definition. The parameters set here are being used both by the `ssd_300()` function that builds the SSD300 model as well as further down by the constructor for the `SSDInputEncoder` object that is needed to run the training. Most of these parameters are needed to define the anchor boxes.
#
# The parameters as set below produce the original SSD300 architecture that was trained on the Pascal VOC datsets, i.e. they are all chosen to correspond exactly to their respective counterparts in the `.prototxt` file that defines the original Caffe implementation. Note that the anchor box scaling factors of the original SSD implementation vary depending on the datasets on which the models were trained. The scaling factors used for the MS COCO datasets are smaller than the scaling factors used for the Pascal VOC datasets. The reason why the list of scaling factors has 7 elements while there are only 6 predictor layers is that the last scaling factor is used for the second aspect-ratio-1 box of the last predictor layer. Refer to the documentation for details.
#
# As mentioned above, the parameters set below are not only needed to build the model, but are also passed to the `SSDInputEncoder` constructor further down, which is responsible for matching and encoding ground truth boxes and anchor boxes during the training. In order to do that, it needs to know the anchor box parameters.

# %%
img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 4 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_pascal
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## 2. Build or load the model
#
# You will want to execute either of the two code cells in the subsequent two sub-sections, not both.

# %% [markdown]
# ### 2.1 Create a new model and load trained VGG-16 weights into it (or trained SSD weights)
#
# If you want to create a new SSD300 model, this is the relevant section for you. If you want to load a previously saved SSD300 model, skip ahead to section 2.2.
#
# The code cell below does the following things:
# 1. It calls the function `ssd_300()` to build the model.
# 2. It then loads the weights file that is found at `weights_path` into the model. You could load the trained VGG-16 weights or you could load the weights of a trained model. If you want to reproduce the original SSD training, load the pre-trained VGG-16 weights. In any case, you need to set the path to the weights file you want to load on your local machine. Download links to all the trained weights are provided in the [README](https://github.com/pierluigiferrari/ssd_keras/blob/master/README.md) of this repository.
# 3. Finally, it compiles the model for the training. In order to do so, we're defining an optimizer (Adam) and a loss function (SSDLoss) to be passed to the `compile()` method.
#
# Normally, the optimizer of choice would be Adam (commented out below), but since the original implementation uses plain SGD with momentum, we'll do the same in order to reproduce the original training. Adam is generally the superior optimizer, so if your goal is not to have everything exactly as in the original training, feel free to switch to Adam. You might need to adjust the learning rate scheduler below slightly in case you use Adam.
#
# Note that the learning rate that is being set here doesn't matter, because further below we'll pass a learning rate scheduler to the training function, which will overwrite any learning rate set here, i.e. what matters are the learning rates that are defined by the learning rate scheduler.
#
# `SSDLoss` is a custom Keras loss function that implements the multi-task that consists of a log loss for classification and a smooth L1 loss for localization. `neg_pos_ratio` and `alpha` are set as in the paper.

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path = 'weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

#adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=sgd, loss=ssd_loss.compute_loss)
# Out:
# tracking <tf.Variable 'conv4_3_norm/conv4_3_norm_gamma:0' shape=(512,) dtype=float32> gamma

# %% [markdown]
# ### 2.2 Load a previously created model
#
# If you have previously created and saved a model and would now like to load it, execute the next code cell. The only thing you need to do here is to set the path to the saved model HDF5 file that you would like to load.
#
# The SSD model contains custom objects: Neither the loss function nor the anchor box or L2-normalization layer types are contained in the Keras core library, so we need to provide them to the model loader.
#
# This next code cell assumes that you want to load a model that was created in 'training' mode. If you want to load a model that was created in 'inference' or 'inference_fast' mode, you'll have to add the `DecodeDetections` or `DecodeDetectionsFast` layer type to the `custom_objects` dictionary below.

# %%
# TODO: Set the path to the `.h5` file of the model to be loaded.
#model_path = 'weights/openimages-new/ssd300_openimages-smol_epoch-146_loss-3.7036_val_loss-4.3773.h5'
model_path = 'openimages-balanced/weights/ssd300_openimages-balanced_epoch-75_loss-4.2201_val_loss-4.5318.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'L2Normalization': L2Normalization,
                                               'compute_loss': ssd_loss.compute_loss})
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# tracking <tf.Variable 'conv4_3_norm/conv4_3_norm_gamma:0' shape=(512,) dtype=float32> gamma
# WARNING:tensorflow:From /content/drive/My Drive/ssd_keras/keras_loss_function/keras_ssd_loss.py:95: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/ssd_keras/keras_loss_function/keras_ssd_loss.py:133: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/drive/My Drive/ssd_keras/keras_loss_function/keras_ssd_loss.py:74: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/ssd_keras/keras_loss_function/keras_ssd_loss.py:166: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %% [markdown]
# ## 3. Set up the data generators for the training
#
# The code cells below set up the data generators for the training and validation datasets to train the model. The settings below reproduce the original SSD training on Pascal VOC 2007 `trainval` plus 2012 `trainval` and validation on Pascal VOC 2007 `test`.
#
# The only thing you need to change here are the filepaths to the datasets on your local machine. Note that parsing the labels from the XML annotations files can take a while.
#
# Note that the generator provides two options to speed up the training. By default, it loads the individual images for a batch from disk. This has two disadvantages. First, for compressed image formats like JPG, this is a huge computational waste, because every image needs to be decompressed again and again every time it is being loaded. Second, the images on disk are likely not stored in a contiguous block of memory, which may also slow down the loading process. The first option that `DataGenerator` provides to deal with this is to load the entire dataset into memory, which reduces the access time for any image to a negligible amount, but of course this is only an option if you have enough free memory to hold the whole dataset. As a second option, `DataGenerator` provides the possibility to convert the dataset into a single HDF5 file. This HDF5 file stores the images as uncompressed arrays in a contiguous block of memory, which dramatically speeds up the loading time. It's not as good as having the images in memory, but it's a lot better than the default option of loading them from their compressed JPG state every time they are needed. Of course such an HDF5 dataset may require significantly more disk space than the compressed images (around 9 GB total for Pascal VOC 2007 `trainval` plus 2012 `trainval` and another 2.6 GB for 2007 `test`). You can later load these HDF5 datasets directly in the constructor.
#
# The original SSD implementation uses a batch size of 32 for the training. In case you run into GPU memory issues, reduce the batch size accordingly. You need at least 7 GB of free GPU memory to train an SSD300 with 20 object classes with a batch size of 32.
#
# The `DataGenerator` itself is fairly generic. I doesn't contain any data augmentation or bounding box encoding logic. Instead, you pass a list of image transformations and an encoder for the bounding boxes in the `transformations` and `label_encoder` arguments of the data generator's `generate()` method, and the data generator will then apply those given transformations and the encoding to the data. Everything here is preset already, but if you'd like to learn more about the data generator and its data augmentation capabilities, take a look at the detailed tutorial in [this](https://github.com/pierluigiferrari/data_generator_object_detection_2d) repository.
#
# The data augmentation settings defined further down reproduce the data augmentation pipeline of the original SSD training. The training generator receives an object `ssd_data_augmentation`, which is a transformation object that is itself composed of a whole chain of transformations that replicate the data augmentation procedure used to train the original Caffe implementation. The validation generator receives an object `resize`, which simply resizes the input images.
#
# An `SSDInputEncoder` object, `ssd_input_encoder`, is passed to both the training and validation generators. As explained above, it matches the ground truth labels to the model's anchor boxes and encodes the box coordinates into the format that the model needs.
#
# In order to train the model on a dataset other than Pascal VOC, either choose `DataGenerator`'s appropriate parser method that corresponds to your data format, or, if `DataGenerator` does not provide a suitable parser for your data format, you can write an additional parser and add it. Out of the box, `DataGenerator` can handle datasets that use the Pascal VOC format (use `parse_xml()`), the MS COCO format (use `parse_json()`) and a wide range of CSV formats (use `parse_csv()`).

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path='openimages-balanced/dataset/dataset_openimages-balanced_train.h5')
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path='openimages-balanced/dataset/dataset_openimages-balanced_val.h5')

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.

# TODO: Set the paths to the datasets here.

# The directories that contain the images.
#VOC_2007_images_dir      = 'VOCdevkit/VOC2007/JPEGImages/' #'../../datasets/VOCdevkit/VOC2007/JPEGImages/'
#VOC_2012_images_dir      = 'VOCdevkit/VOC2012/JPEGImages/' #'../../datasets/VOCdevkit/VOC2012/JPEGImages/'
openImagesTrainImagesDir = "openimages-balanced/images/"
openImagesValImagesDir = "openimages-balanced/images/"

# The directories that contain the annotations.
#VOC_2007_annotations_dir      = 'VOCdevkit/VOC2007/Annotations/' #'../../datasets/VOCdevkit/VOC2007/Annotations/'
#VOC_2012_annotations_dir      = 'VOCdevkit/VOC2012/Annotations/' #'../../datasets/VOCdevkit/VOC2012/Annotations/'
openImagesTrainAnnotationsDir = "openimages-balanced/annotations/"
openImagesValAnnotationsDir = "openimages-balanced/annotations/"

# The paths to the image sets.
#VOC_2007_train_image_set_filename    = 'VOCdevkit/VOC2007/ImageSets/Main/train.txt' #'../../datasets/VOCdevkit/VOC2007/ImageSets/Main/train.txt'
#VOC_2012_train_image_set_filename    = 'VOCdevkit/VOC2012/ImageSets/Main/train.txt' #'../../datasets/VOCdevkit/VOC2012/ImageSets/Main/train.txt'
#VOC_2007_val_image_set_filename      = 'VOCdevkit/VOC2007/ImageSets/Main/val.txt' #'../../datasets/VOCdevkit/VOC2007/ImageSets/Main/val.txt'
#VOC_2012_val_image_set_filename      = 'VOCdevkit/VOC2012/ImageSets/Main/val.txt' #'../../datasets/VOCdevkit/VOC2012/ImageSets/Main/val.txt'
#VOC_2007_trainval_image_set_filename = 'VOCdevkit/VOC2007/ImageSets/Main/trainval.txt' #'../../datasets/VOCdevkit/VOC2007/ImageSets/Main/trainval.txt'
#VOC_2012_trainval_image_set_filename = 'VOCdevkit/VOC2012/ImageSets/Main/trainval.txt' #'../../datasets/VOCdevkit/VOC2012/ImageSets/Main/trainval.txt'
#VOC_2007_test_image_set_filename     = 'VOCdevkit/VOC2007/ImageSets/Main/test.txt' #'../../datasets/VOCdevkit/VOC2007/ImageSets/Main/test.txt'
openImagesTrainImageSet = "openimages-balanced/train_ImageID.txt"
openImagesValImageSet = "openimages-balanced/val_ImageID.txt"

# The XML parser needs to now what object class names to look for and in which order to map them to integers.
#classes = ['background',
           #'aeroplane', 'bicycle', 'bird', 'boat',
           #'bottle', 'bus', 'car', 'cat',
           #'chair', 'cow', 'diningtable', 'dog',
           #'horse', 'motorbike', 'person', 'pottedplant',
           #'sheep', 'sofa', 'train', 'tvmonitor']
classes = ['background','Man', 'Woman' , 'Boy' , 'Girl']


#train_dataset.parse_xml(images_dirs=[VOC_2007_images_dir,
                                     #VOC_2012_images_dir],
                        #image_set_filenames=[VOC_2007_trainval_image_set_filename,
                                             #VOC_2012_trainval_image_set_filename],
                        #annotations_dirs=[VOC_2007_annotations_dir,
                                          #VOC_2012_annotations_dir],
                        #classes=classes,
                        #include_classes='all',
                        #exclude_truncated=False,
                        #exclude_difficult=False,
                        #ret=False)

#train_dataset.parse_xml(images_dirs=[openImagesTrainImagesDir],
                        #image_set_filenames=[openImagesTrainImageSet],
                        #annotations_dirs=[openImagesTrainAnnotationsDir],
                        #classes=classes,
                        #include_classes='all',
                        #exclude_truncated=False,
                        #exclude_difficult=False,
                        #ret=False)

#val_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                      #image_set_filenames=[VOC_2007_test_image_set_filename],
                      #annotations_dirs=[VOC_2007_annotations_dir],
                      #classes=classes,
                      #include_classes='all',
                      #exclude_truncated=False,
                      #exclude_difficult=True,
                      #ret=False)

#val_dataset.parse_xml(images_dirs=[openImagesValImagesDir],
                      #image_set_filenames=[openImagesValImageSet],
                      #annotations_dirs=[openImagesValAnnotationsDir],
                      #classes=classes,
                      #include_classes='all',
                      #exclude_truncated=False,
                      #exclude_difficult=False,
                      #ret=False)

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

#train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07+12_trainval.h5',
                                  #resize=False,
                                  #variable_image_size=True,
                                  #verbose=True)

#train_dataset.create_hdf5_dataset(file_path='openimages-balanced/dataset/dataset_openimages-balanced_train.h5',
                                  #resize=False,
                                  #variable_image_size=True,
                                  #verbose=True)

#val_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',
                                #resize=False,
                                #variable_image_size=True,
                                #verbose=True)

#val_dataset.create_hdf5_dataset(file_path='openimages-balanced/dataset/dataset_openimages-balanced_val.h5',
                                #resize=False,
                                #variable_image_size=True,
                                #verbose=True)
# Out:
# Loading labels: 100%|██████████| 8000/8000 [01:04<00:00, 124.09it/s]
# Loading image IDs: 100%|██████████| 8000/8000 [00:00<00:00, 10189.30it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 8000/8000 [00:01<00:00, 7794.56it/s]
# Loading labels: 100%|██████████| 1000/1000 [00:07<00:00, 133.80it/s]
# Loading image IDs: 100%|██████████| 1000/1000 [00:00<00:00, 10091.05it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 1000/1000 [00:00<00:00, 7735.49it/s]

# %%
# 3: Set the batch size.

batch_size = 64 #32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  8000
# Number of images in the validation dataset:	  1000

# %% [markdown]
# ## 4. Set the remaining training parameters
#
# We've already chosen an optimizer and set the batch size above, now let's set the remaining training parameters. I'll set one epoch to consist of 1,000 training steps. The next code cell defines a learning rate schedule that replicates the learning rate schedule of the original Caffe implementation for the training of the SSD300 Pascal VOC "07+12" model. That model was trained for 120,000 steps with a learning rate of 0.001 for the first 80,000 steps, 0.0001 for the next 20,000 steps, and 0.00001 for the last 20,000 steps. If you're training on a different dataset, define the learning rate schedule however you see fit.
#
# I'll set only a few essential Keras callbacks below, feel free to add more callbacks if you want TensorBoard summaries or whatever. We obviously need the learning rate scheduler and we want to save the best models during the training. It also makes sense to continuously stream our training history to a CSV log file after every epoch, because if we didn't do that, in case the training terminates with an exception at some point or if the kernel of this Jupyter notebook dies for some reason or anything like that happens, we would lose the entire history for the trained epochs. Finally, we'll also add a callback that makes sure that the training terminates if the loss becomes `NaN`. Depending on the optimizer you use, it can happen that the loss becomes `NaN` during the first iterations of the training. In later iterations it's less of a risk. For example, I've never seen a `NaN` loss when I trained SSD using an Adam optimizer, but I've seen a `NaN` loss a couple of times during the very first couple of hundred training steps of training a new model when I used an SGD optimizer.

# %%
# Define a learning rate schedule.

def lr_schedule(epoch):
    if epoch < 200:
        return 0.001
    elif epoch < 500:
        return 0.0001
    else:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='openimages-balanced/weights/ssd300_openimages-balanced_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5', #filepath='ssd300_pascal_07+12_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
#model_checkpoint.best = 

csv_logger = CSVLogger(filename='openimages-balanced/ssd300_openimages-balanced_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %% [markdown]
# ## 5. Train

# %% [markdown]
# In order to reproduce the training of the "07+12" model mentioned above, at 1,000 training steps per epoch you'd have to train for 120 epochs. That is going to take really long though, so you might not want to do all 120 epochs in one go and instead train only for a few epochs at a time. You can find a summary of a full training [here](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md).
#
# In order to only run a partial training and resume smoothly later on, there are a few things you should note:
# 1. Always load the full model if you can, rather than building a new model and loading previously saved weights into it. Optimizers like SGD or Adam keep running averages of past gradient moments internally. If you always save and load full models when resuming a training, then the state of the optimizer is maintained and the training picks up exactly where it left off. If you build a new model and load weights into it, the optimizer is being initialized from scratch, which, especially in the case of Adam, leads to small but unnecessary setbacks every time you resume the training with previously saved weights.
# 2. In order for the learning rate scheduler callback above to work properly, `fit_generator()` needs to know which epoch we're in, otherwise it will start with epoch 0 every time you resume the training. Set `initial_epoch` to be the next epoch of your training. Note that this parameter is zero-based, i.e. the first epoch is epoch 0. If you had trained for 10 epochs previously and now you'd want to resume the training from there, you'd set `initial_epoch = 10` (since epoch 10 is the eleventh epoch). Furthermore, set `final_epoch` to the last epoch you want to run. To stick with the previous example, if you had trained for 10 epochs previously and now you'd want to train for another 10 epochs, you'd set `initial_epoch = 10` and `final_epoch = 20`.
# 3. In order for the model checkpoint callback above to work correctly after a kernel restart, set `model_checkpoint.best` to the best validation loss from the previous training. If you don't do this and a new `ModelCheckpoint` object is created after a kernel restart, that object obviously won't know what the last best validation loss was, so it will always save the weights of the first epoch of your new training and record that loss as its new best loss. This isn't super-important, I just wanted to mention it.

# %%
model.summary()

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 90
final_epoch     = 90 # originally 120
steps_per_epoch = 1000 # originally 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 91/110
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.001.
#  765/1000 [=====================>........] - ETA: 8:33 - loss: 4.0680

# %%
model.save("openimages-balanced/weights/Epoch 90.h5")

# %% [markdown]
# ## 6. Make predictions
#
# Now let's make some predictions on the validation dataset with the trained model. For convenience we'll use the validation generator that we've already set up above. Feel free to change the batch size.
#
# You can set the `shuffle` option to `False` if you would like to check the model's progress on the same image(s) over the course of the training.

# %%
# additional code to parse xml data of test set

openImagesTestImagesDir = "openimages-balanced/images/"
openImagesTestAnnotationsDir = "openimages-balanced/annotations/"
openImagesTestImageSet = "openimages-balanced/test_ImageID.txt"

test_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

testParseResults = test_dataset.parse_xml(images_dirs=[openImagesTestImagesDir],
                  image_set_filenames=[openImagesTestImageSet],
                  annotations_dirs=[openImagesTestAnnotationsDir],
                  classes=classes,
                  include_classes='all',
                  exclude_truncated=False,
                  exclude_difficult=True,
                  ret=True)

convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

test_dataset.create_hdf5_dataset(file_path='openimages-balanced/dataset/dataset_openimages-balanced_test-new.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)

# %%
# additional code to switch over to test set

openImagesTestImageSet = "openimages-balanced/test_ImageID.txt"

test_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path='openimages-balanced/dataset/dataset_openimages-balanced_test-new.h5')

convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)
# Out:
# Loading labels: 100%|██████████| 1000/1000 [00:18<00:00, 52.81it/s]
# Loading image IDs: 100%|██████████| 1000/1000 [00:00<00:00, 9538.69it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 1000/1000 [00:00<00:00, 2844.82it/s]

# %%
test_dataset_size = test_dataset.get_dataset_size()
print(test_dataset_size)
# Out:
# 1000

# %%
# 1: Set the generator for the predictions.

final_epoch     = 76

test_dataset_size = test_dataset.get_dataset_size()

#predict_generator = val_dataset.generate(batch_size=10,
predict_generator = test_dataset.generate(batch_size=test_dataset_size,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'image_ids',#'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 5 # Which batch item to look at


#print("Image:", batch_filesnames[i])
print()

for j in range(len(batch_original_labels)):
  print("Image "+str(j)+": "+ batch_filenames[j])
  #print("Ground truth box:"+ str(j))
  #print(np.array(batch_original_labels[j]))
  print("\n")
# Out:
# Image 0: test/f82430c155bde768
#
#
# Image 1: test/5139400fff7bb583
#
#
# Image 2: test/5126c87695b9c344
#
#
# Image 3: test/e0805595ca05c4ac
#
#
# Image 4: test/0a593d23f391ce70
#
#
# Image 5: test/005e297eed629e8b
#
#
# Image 6: test/9363dea9cef164d4
#
#
# Image 7: test/618775e4ea2c093d
#
#
# Image 8: test/48f7191ced82615b
#
#
# Image 9: test/031716b4d2adb056
#
#
# Image 10: test/00156ac2ee0c3d58
#
#
# Image 11: test/f40ca3d2855fb5e6
#
#
# Image 12: test/6614c34676b13a3d
#
#
# Image 13: test/54245596262c9b66
#
#
# Image 14: test/8988f0b576ab17bd
#
#
# Image 15: test/e02bf443cea6e155
#
#
# Image 16: test/418be460cdc1cc61
#
#
# Image 17: test/cf6b080ae23a1f72
#
#
# Image 18: test/6033885448686771
#
#
# Image 19: test/f0f9bfb6b81dc05e
#
#
# Image 20: test/d23e87da605fa643
#
#
# Image 21: test/f4cb493c0fa3f8c2
#
#
# Image 22: test/1bd904846b4ac438
#
#
# Image 23: test/1d92602d14e3200f
#
#
# Image 24: test/5ff33fcd1bde171a
#
#
# Image 25: test/734c97655e610e97
#
#
# Image 26: test/ac1321300c6b9f4b
#
#
# Image 27: test/c843b622c2e3bff1
#
#
# Image 28: test/6c7c097f8ae9513f
#
#
# Image 29: test/94438d1243be98eb
#
#
# Image 30: test/e8952554349993bf
#
#
# Image 31: test/a308642e4d4791c6
#
#
# Image 32: test/ef885d094dbb461f
#
#
# Image 33: test/31c22a9cd9cce26a
#
#
# Image 34: test/8aa642ef572d2231
#
#
# Image 35: test/70cf4ea22fbd97cf
#
#
# Image 36: test/c2c71a739b95310e
#
#
# Image 37: test/93488d00705731d4
#
#
# Image 38: test/0e9d7928364dce7e
#
#
# Image 39: test/115b6debaf2bf522
#
#
# Image 40: test/d735617a8927f56d
#
#
# Image 41: test/247e10c243cec84c
#
#
# Image 42: test/cc29a227aacd4a1c
#
#
# Image 43: test/6064ffc7815edf27
#
#
# Image 44: test/7bdfd75512ff310b
#
#
# Image 45: test/0e085be1388be9ff
#
#
# Image 46: test/3a1db23e91d589fe
#
#
# Image 47: test/9c8fcf1c70839d69
#
#
# Image 48: test/9d0d6ade14d9bd16
#
#
# Image 49: test/4960597581e5c337
#
#
# Image 50: test/c8a749531c172a42
#
#
# Image 51: test/c58d3ad5a12c125d
#
#
# Image 52: test/45fb60ae102d9409
#
#
# Image 53: test/c9825aacb0ea068c
#
#
# Image 54: test/977428426d455644
#
#
# Image 55: test/590318998765182d
#
#
# Image 56: test/ec436f4a7219cf1a
#
#
# Image 57: test/33d13e75c202806d
#
#
# Image 58: test/8540f97669ba45e7
#
#
# Image 59: test/88d6c8356cfa5cbe
#
#
# Image 60: test/6cf42e1eff41dd3d
#
#
# Image 61: test/6227b1aa3d456707
#
#
# Image 62: test/19ce47859fe84403
#
#
# Image 63: test/f2885fec93210d0b
#
#
# Image 64: test/a6dde41d9dd261db
#
#
# Image 65: test/9e4d5eb78c5de265
#
#
# Image 66: test/345087c2b892c55e
#
#
# Image 67: test/3501ec8b411cddd5
#
#
# Image 68: test/ebb110baeb96ff53
#
#
# Image 69: test/f0946dfc9bb1e3a9
#
#
# Image 70: test/a17e24abd493cc76
#
#
# Image 71: test/e9f7c51323164ad2
#
#
# Image 72: test/6b99760f0923ea9a
#
#
# Image 73: test/04ef633c41462641
#
#
# Image 74: test/1fb38520dcc3a34f
#
#
# Image 75: test/64ceec357d0377ed
#
#
# Image 76: test/d50064dfabf0fbd5
#
#
# Image 77: test/f470855b33f7b961
#
#
# Image 78: test/423b0463da0aeedd
#
#
# Image 79: test/cf0d9e7b9f80957f
#
#
# Image 80: test/df382ad01eb02b1b
#
#
# Image 81: test/027dafd1b0d6b215
#
#
# Image 82: test/c04ea121124a1753
#
#
# Image 83: test/2d179c5d6bc2874c
#
#
# Image 84: test/d2660ebdfe8dbb92
#
#
# Image 85: test/07510743cf79a800
#
#
# Image 86: test/7b8c12c9335ebd58
#
#
# Image 87: test/bffb7e6a2e5a8be9
#
#
# Image 88: test/27d260b4bb5161b0
#
#
# Image 89: test/5e9a83f191ef5c8c
#
#
# Image 90: test/cec6f37d4a127f66
#
#
# Image 91: test/ffc4e88b6c8f798a
#
#
# Image 92: test/010006993a980b92
#
#
# Image 93: test/587bb9cd7dd50c20
#
#
# Image 94: test/97bb84a37350dce3
#
#
# Image 95: test/20c3ecd4cebd3c32
#
#
# Image 96: test/13ba42071a558486
#
#
# Image 97: test/5975fbfe0a1340fa
#
#
# Image 98: test/330071af6d2cf94d
#
#
# Image 99: test/561fb0f52a5385ab
#
#
# Image 100: test/ff403790c93a9a11
#
#
# Image 101: test/4cbc8a22788b1094
#
#
# Image 102: test/c3b11f5087b66011
#
#
# Image 103: test/70fb78d8ad307b8f
#
#
# Image 104: test/4aaed40f56fe84d0
#
#
# Image 105: test/b7bf5d9004c44486
#
#
# Image 106: test/c91d4e37eedf74f5
#
#
# Image 107: test/7aa252b07906b2a1
#
#
# Image 108: test/38c4dec4544f6aa4
#
#
# Image 109: test/9b0ab1fc34ba01dc
#
#
# Image 110: test/6e08eec11fe1f8c9
#
#
# Image 111: test/f74ac96e9d834f7d
#
#
# Image 112: test/d35e094cfd1d95e2
#
#
# Image 113: test/a95a173a71c15746
#
#
# Image 114: test/775af25836d00d50
#
#
# Image 115: test/a9c496560dad09ff
#
#
# Image 116: test/cb75e6ef5117e538
#
#
# Image 117: test/9d843b2a03558a69
#
#
# Image 118: test/4792c9e84a7c8bb5
#
#
# Image 119: test/5c4060e9777569cd
#
#
# Image 120: test/5f49eb9686474309
#
#
# Image 121: test/5bae7278458c8946
#
#
# Image 122: test/151560bafaab1156
#
#
# Image 123: test/25c09243e33d27cf
#
#
# Image 124: test/269f7348ede3d5a0
#
#
# Image 125: test/717a200a9c865a50
#
#
# Image 126: test/fec4bbd3dd410872
#
#
# Image 127: test/4fd7741bd29bc883
#
#
# Image 128: test/7d6a2d3d88297edb
#
#
# Image 129: test/3f244ad59da3aca5
#
#
# Image 130: test/02d22b1f4748a862
#
#
# Image 131: test/8c94cd69d1baf6db
#
#
# Image 132: test/58018e60c3d58e77
#
#
# Image 133: test/03df76cf986b3492
#
#
# Image 134: test/63de2458b37d8c78
#
#
# Image 135: test/bdbbfc0c4372e3a1
#
#
# Image 136: test/a49a5b38e6f596bc
#
#
# Image 137: test/2e9dfe279f12c972
#
#
# Image 138: test/4226aedbc485f6be
#
#
# Image 139: test/ff7b9ad7717e11dc
#
#
# Image 140: test/0ed1fc34936188cd
#
#
# Image 141: test/65ef05f7a31236d2
#
#
# Image 142: test/7d0ba12d7d84ee5e
#
#
# Image 143: test/b02b5149b558d299
#
#
# Image 144: test/785df5bb4a743258
#
#
# Image 145: test/a33070e7c5a3d444
#
#
# Image 146: test/e1a9d37751e489f4
#
#
# Image 147: test/6cc111063a7a79ee
#
#
# Image 148: test/de43326ce30e279b
#
#
# Image 149: test/8765b8fea1acb331
#
#
# Image 150: test/6a99e86a8d2ba501
#
#
# Image 151: test/f5bd9c70b3fe58a8
#
#
# Image 152: test/ec7be5df727080cc
#
#
# Image 153: test/d9e9653b6e5d755f
#
#
# Image 154: test/03c0d701c94b620c
#
#
# Image 155: test/58c4548131cefffc
#
#
# Image 156: test/ac02413770bd94bc
#
#
# Image 157: test/d5363be9150fe531
#
#
# Image 158: test/059125932a91441a
#
#
# Image 159: test/d8c41921c71f5b40
#
#
# Image 160: test/203f64277331c12e
#
#
# Image 161: test/cf5967b2c0eb3ec6
#
#
# Image 162: test/122cbe069b17af5a
#
#
# Image 163: test/0d086f02ba27de9d
#
#
# Image 164: test/4f4ae1baabc991da
#
#
# Image 165: test/b44bfa007f76ee99
#
#
# Image 166: test/e717cf5bf8bd5ba8
#
#
# Image 167: test/8c741582141ae125
#
#
# Image 168: test/7e719ebd59673e6f
#
#
# Image 169: test/7bd284cbeb531e25
#
#
# Image 170: test/fc380b333d99489b
#
#
# Image 171: test/7d30843c3956ee9c
#
#
# Image 172: test/67da83c5dd3a6bea
#
#
# Image 173: test/7bce689cc339f5a1
#
#
# Image 174: test/674d9b5f52aee8a6
#
#
# Image 175: test/a04d39a504b89b4e
#
#
# Image 176: test/c39a9f18e95e8151
#
#
# Image 177: test/93395fd177fcced2
#
#
# Image 178: test/198e70dc30eca5e6
#
#
# Image 179: test/94fdfcfc36ac8568
#
#
# Image 180: test/d0a4b639df65598c
#
#
# Image 181: test/44ff0c0e2a05c5b6
#
#
# Image 182: test/7adfcbd5fe478dc1
#
#
# Image 183: test/508d81b51aad0aae
#
#
# Image 184: test/9d4f7ba2b0d50cc9
#
#
# Image 185: test/2606ff37c58feb37
#
#
# Image 186: test/9d3a59cc8c976dc2
#
#
# Image 187: test/4f13fec7e242430c
#
#
# Image 188: test/3361fe2b83bb7613
#
#
# Image 189: test/22a2809f0801b0ab
#
#
# Image 190: test/ee1e4460fb15e927
#
#
# Image 191: test/9e0178d95c3ffdc2
#
#
# Image 192: test/5617316eef77e90a
#
#
# Image 193: test/005304a16107b370
#
#
# Image 194: test/20be7dc4008e7cb7
#
#
# Image 195: test/f4cb146ab4cea048
#
#
# Image 196: test/fb3dafb50c5ce49d
#
#
# Image 197: test/923c1a8b3e828107
#
#
# Image 198: test/addd2b526748b761
#
#
# Image 199: test/e9de9e1efb1ce29c
#
#
# Image 200: test/f5a034752153119d
#
#
# Image 201: test/b87888704d1df438
#
#
# Image 202: test/b2d1ba5bb7c0d868
#
#
# Image 203: test/ee0abebf2356e40f
#
#
# Image 204: test/26703203109ea76b
#
#
# Image 205: test/1467a36d490d1750
#
#
# Image 206: test/f784dbf99afe789e
#
#
# Image 207: test/264f7c1608b13f83
#
#
# Image 208: test/c025163e959864e6
#
#
# Image 209: test/53face6a34615f02
#
#
# Image 210: test/7b2756a678e0b804
#
#
# Image 211: test/5d61eac1650231cf
#
#
# Image 212: test/75a3556c95321ac2
#
#
# Image 213: test/93696dee806962dd
#
#
# Image 214: test/09ae5f0def30b66d
#
#
# Image 215: test/98c2af63255677a7
#
#
# Image 216: test/fd52eec612789b03
#
#
# Image 217: test/ac5f5ab4be241485
#
#
# Image 218: test/a24d062ba2201138
#
#
# Image 219: test/3591fceeddffb25f
#
#
# Image 220: test/a33e866ebd3a3c1b
#
#
# Image 221: test/c5e24349b62ff866
#
#
# Image 222: test/fbfdbae790a784c2
#
#
# Image 223: test/63daabf9997e0c85
#
#
# Image 224: test/f6b02b308e37227c
#
#
# Image 225: test/b4b5d2052e31bea5
#
#
# Image 226: test/3f6bbca6f95c7be2
#
#
# Image 227: test/93106fc07b061593
#
#
# Image 228: test/09c86aeeacffefd6
#
#
# Image 229: test/8787d352c1bf756e
#
#
# Image 230: test/e587396cf6d35405
#
#
# Image 231: test/c2b092537b3d8f64
#
#
# Image 232: test/fc6fd707ddfdecc3
#
#
# Image 233: test/597d9e733a563df7
#
#
# Image 234: test/37dd94623bc33e92
#
#
# Image 235: test/392089bb62ada865
#
#
# Image 236: test/e3557cd0f67afee4
#
#
# Image 237: test/80f83da8bdc0ae70
#
#
# Image 238: test/3e7d4f598d539875
#
#
# Image 239: test/059520433a9809d0
#
#
# Image 240: test/3a3ecda72511002f
#
#
# Image 241: test/6247ac43956e7cfa
#
#
# Image 242: test/6f797299e86346e6
#
#
# Image 243: test/5de2564634fe0d1a
#
#
# Image 244: test/be2f6c2b7fa53d8c
#
#
# Image 245: test/c7a95189a84ab64d
#
#
# Image 246: test/5b3d8eacb52b1468
#
#
# Image 247: test/0334426756e025bc
#
#
# Image 248: test/836fa14b9a909258
#
#
# Image 249: test/ca8a9165a326e722
#
#
# Image 250: test/08a44e93ca2897f6
#
#
# Image 251: test/067e31ac1d7266d9
#
#
# Image 252: test/9ce3a067de6a0255
#
#
# Image 253: test/2116191d557d651c
#
#
# Image 254: test/d43521801fbb54cd
#
#
# Image 255: test/81843a75fdeb2daf
#
#
# Image 256: test/0f27a4b39c927275
#
#
# Image 257: test/6aba33edb9fe95cb
#
#
# Image 258: test/6f7831f8fc471205
#
#
# Image 259: test/3862e9b090b3f3bb
#
#
# Image 260: test/560045632b95c38c
#
#
# Image 261: test/3669662d1417c254
#
#
# Image 262: test/ae7f5545d5f15aa6
#
#
# Image 263: test/b1633e601eeeb048
#
#
# Image 264: test/444ce60cdef212fb
#
#
# Image 265: test/9bc4e5679f8ca7bb
#
#
# Image 266: test/db2d0e23be0b9581
#
#
# Image 267: test/95ed579ee1c31eb5
#
#
# Image 268: test/f452b0a53243dd43
#
#
# Image 269: test/7658e40ac15c693a
#
#
# Image 270: test/0e105ec6ccf5c23c
#
#
# Image 271: test/201444c6c7a702b0
#
#
# Image 272: test/c4338df04f79b0f0
#
#
# Image 273: test/1e8e97ae16cca52e
#
#
# Image 274: test/f5bec5bc72259489
#
#
# Image 275: test/10d71346afbeb58e
#
#
# Image 276: test/1ae3ff07a3b8c821
#
#
# Image 277: test/e3ce9563e3557f95
#
#
# Image 278: test/a69916691bc04b97
#
#
# Image 279: test/a53d496a7a82b60f
#
#
# Image 280: test/305eabd57a204cfc
#
#
# Image 281: test/a1d70803ab8cd79f
#
#
# Image 282: test/eb1f31977655f5e9
#
#
# Image 283: test/5641455545707153
#
#
# Image 284: test/abc8ffde8bfab388
#
#
# Image 285: test/52b8428114aab942
#
#
# Image 286: test/62c75e993beb5e37
#
#
# Image 287: test/ac2fbac535c39792
#
#
# Image 288: test/df95ab534bab2bc9
#
#
# Image 289: test/36510c238ed56073
#
#
# Image 290: test/03a80d9b80d8082b
#
#
# Image 291: test/f3e534908176f8f6
#
#
# Image 292: test/938bc5c0caa8055a
#
#
# Image 293: test/dd77d31dc3ebfd5a
#
#
# Image 294: test/9350f76d7a252e61
#
#
# Image 295: test/17335464bad50052
#
#
# Image 296: test/43b3da44901f1303
#
#
# Image 297: test/0159c0e9e26e49ce
#
#
# Image 298: test/4218dcab8d1c023b
#
#
# Image 299: test/30a546b433144732
#
#
# Image 300: test/7a3e6fea7b46e1ac
#
#
# Image 301: test/bb2d37522e52f6fc
#
#
# Image 302: test/62c593f035946ebc
#
#
# Image 303: test/df06bb439195c017
#
#
# Image 304: test/7c6b553e4cfbcc45
#
#
# Image 305: test/5c3b3dd1f4c4a681
#
#
# Image 306: test/29e19e55d551a520
#
#
# Image 307: test/5bb5c07954c50aa9
#
#
# Image 308: test/ebb059d8ef36c089
#
#
# Image 309: test/26eba60bf2828382
#
#
# Image 310: test/64055a119a99ff60
#
#
# Image 311: test/2225b2c55ccdb2d6
#
#
# Image 312: test/1a30bc4b72bf51f2
#
#
# Image 313: test/b101309cbb503113
#
#
# Image 314: test/65e18e3f65bf89ae
#
#
# Image 315: test/b34d853c78cac35a
#
#
# Image 316: test/483b51b90bef9895
#
#
# Image 317: test/c60e4afce27cf5dd
#
#
# Image 318: test/fe9d080481f6d3d7
#
#
# Image 319: test/d02ec3c8b01563e0
#
#
# Image 320: test/f6152a8ba6e644b1
#
#
# Image 321: test/dc9da4e096dd0813
#
#
# Image 322: test/359d9791156e4dbc
#
#
# Image 323: test/ffede35b67aab7d2
#
#
# Image 324: test/c9d101a0d3c33deb
#
#
# Image 325: test/36798fac28352b1c
#
#
# Image 326: test/5621ee64f384470c
#
#
# Image 327: test/53ed581dda907c8b
#
#
# Image 328: test/824952209908f287
#
#
# Image 329: test/d1266f7cd519f745
#
#
# Image 330: test/2d5fecf5315419cc
#
#
# Image 331: test/e0c3ebfc6b4c0f90
#
#
# Image 332: test/3e5f0e25329926f4
#
#
# Image 333: test/ba0498ce53cb483f
#
#
# Image 334: test/531c8d764432ed50
#
#
# Image 335: test/c9c1813883ee088c
#
#
# Image 336: test/29b0b6fdac6ff269
#
#
# Image 337: test/a1f38be2905908b0
#
#
# Image 338: test/b8bc01d577165acc
#
#
# Image 339: test/3767b86cb78bef13
#
#
# Image 340: test/6f786fcf4f2eb451
#
#
# Image 341: test/4d95b874bc7801ef
#
#
# Image 342: test/a19cad70e397a8c1
#
#
# Image 343: test/e84f6994de427de9
#
#
# Image 344: test/a5510558f0dc5589
#
#
# Image 345: test/5f9eec8ea0109185
#
#
# Image 346: test/5982b76dff9699d1
#
#
# Image 347: test/caadf773368039a2
#
#
# Image 348: test/77b3a7413941c16d
#
#
# Image 349: test/9c68351d686cbf3d
#
#
# Image 350: test/f072464df71208e8
#
#
# Image 351: test/1082cbe62ac8fe05
#
#
# Image 352: test/7425d828852c6e05
#
#
# Image 353: test/f24b6d2e4a6e3467
#
#
# Image 354: test/41d4bdc67ce4d1c6
#
#
# Image 355: test/a853826ece613fda
#
#
# Image 356: test/27c6327dec331040
#
#
# Image 357: test/1aa10fee2d5f8aa0
#
#
# Image 358: test/65433c5a09f63551
#
#
# Image 359: test/a7c86c20e06c095d
#
#
# Image 360: test/a4442587774e19c9
#
#
# Image 361: test/4d1aa2e121977f7c
#
#
# Image 362: test/ac70f58bbb130fc3
#
#
# Image 363: test/0a6c0209c9aa3363
#
#
# Image 364: test/e3838188cb36822b
#
#
# Image 365: test/62b53b417b02e75c
#
#
# Image 366: test/96d40d1cc61b5212
#
#
# Image 367: test/676bec8ddc1c130d
#
#
# Image 368: test/05b802246e18c682
#
#
# Image 369: test/05863d03cc53695d
#
#
# Image 370: test/d9047db41f6d69c8
#
#
# Image 371: test/f08e99e211ddaf27
#
#
# Image 372: test/8acc974557f6c888
#
#
# Image 373: test/c84de15018e0cfe4
#
#
# Image 374: test/8f47e94ffe35c08b
#
#
# Image 375: test/d38d644842b0b3b0
#
#
# Image 376: test/86f725d6e39799eb
#
#
# Image 377: test/aebfe27dc4b1b3ba
#
#
# Image 378: test/e442b41a459d6695
#
#
# Image 379: test/073b3367710e71be
#
#
# Image 380: test/590f9b00905fe5d8
#
#
# Image 381: test/c6737278e2845421
#
#
# Image 382: test/492b6010e13e51b7
#
#
# Image 383: test/18b4ed30f44419b5
#
#
# Image 384: test/22902f98b24b705c
#
#
# Image 385: test/d171c781cfea9d98
#
#
# Image 386: test/f45b90353ea21448
#
#
# Image 387: test/cb234218c5ce37d7
#
#
# Image 388: test/0bee6b7507845d34
#
#
# Image 389: test/de8ede02f0a7d4c8
#
#
# Image 390: test/72a6bae165a0b0cd
#
#
# Image 391: test/373c48cabfb0168e
#
#
# Image 392: test/2a28eabff35bd2f7
#
#
# Image 393: test/e84ae19f54c41c00
#
#
# Image 394: test/a8eb1407e107144f
#
#
# Image 395: test/96df64f2c1aaecef
#
#
# Image 396: test/10cdaca6d67dd98c
#
#
# Image 397: test/e1e05eb06327f89f
#
#
# Image 398: test/ae502c37b26c72f8
#
#
# Image 399: test/246840056187710d
#
#
# Image 400: test/00b96ff2060fcfa2
#
#
# Image 401: test/d9400411a6fd90f7
#
#
# Image 402: test/0eed10a64602dccf
#
#
# Image 403: test/3974f503366bcd92
#
#
# Image 404: test/ee03738597984544
#
#
# Image 405: test/9553b9608577b74b
#
#
# Image 406: test/ce1f2e2a166d185a
#
#
# Image 407: test/5e106cd106e265d9
#
#
# Image 408: test/1d8d480ee9334149
#
#
# Image 409: test/b9b426c5e422455e
#
#
# Image 410: test/3042b8ad77c737f3
#
#
# Image 411: test/6bbb2094073681dd
#
#
# Image 412: test/a7cdac6d48c31a49
#
#
# Image 413: test/0f050297e01c8c08
#
#
# Image 414: test/627ceafe0ac6eef7
#
#
# Image 415: test/fea1c0d93e92fb61
#
#
# Image 416: test/3985377d4e892b37
#
#
# Image 417: test/ed3c874c062479aa
#
#
# Image 418: test/b5cfbb6af18c27da
#
#
# Image 419: test/6b6a9e01ab46404c
#
#
# Image 420: test/138a92a78193bb7b
#
#
# Image 421: test/6cc42293ce185c89
#
#
# Image 422: test/69dbd2db13bd1994
#
#
# Image 423: test/1658ee700cc5cf6e
#
#
# Image 424: test/404ebe15c0979189
#
#
# Image 425: test/150a2c9c7f6d43e7
#
#
# Image 426: test/5c5e755aef2f2366
#
#
# Image 427: test/b4637efd9aeff4b8
#
#
# Image 428: test/7151187b70a7a9a0
#
#
# Image 429: test/c6888f370f5469f4
#
#
# Image 430: test/c10c10eecc532b24
#
#
# Image 431: test/48ea1aece690023f
#
#
# Image 432: test/c5a12ff9a573f5c8
#
#
# Image 433: test/9e157c70d7a40947
#
#
# Image 434: test/808bfc45836b5783
#
#
# Image 435: test/6c07560197c23c6c
#
#
# Image 436: test/57a7254dcf8e0b18
#
#
# Image 437: test/27013b446c95c95b
#
#
# Image 438: test/c91e1f23514504a2
#
#
# Image 439: test/4213f70e782c6d9e
#
#
# Image 440: test/3b3d545280602f3b
#
#
# Image 441: test/97bd4d44d3eba27d
#
#
# Image 442: test/e4af06d7c8b74d86
#
#
# Image 443: test/d0f5e478b3956b0a
#
#
# Image 444: test/717eb8ceac99a2cc
#
#
# Image 445: test/68ff0b39dbc6574b
#
#
# Image 446: test/7efa491b25b5dd28
#
#
# Image 447: test/ef98838a8b76bbad
#
#
# Image 448: test/84152b39e3c3f2aa
#
#
# Image 449: test/3336248fb42c5466
#
#
# Image 450: test/a9ece2ef7f0bb1cd
#
#
# Image 451: test/82660e16ff8b11ea
#
#
# Image 452: test/6a30a282543fd175
#
#
# Image 453: test/3516ffd0eb5ba846
#
#
# Image 454: test/dd73e8250e032d35
#
#
# Image 455: test/c09a6e516e6130a9
#
#
# Image 456: test/b5b95fce8631ff1c
#
#
# Image 457: test/0b84a70c2ac0c874
#
#
# Image 458: test/59440580cb80e791
#
#
# Image 459: test/013dbf33cfba6453
#
#
# Image 460: test/cb7ef4061559070c
#
#
# Image 461: test/0038b12aeccdcb7e
#
#
# Image 462: test/1a2d77e59fcd210a
#
#
# Image 463: test/07afbe28e286087e
#
#
# Image 464: test/9b802f58f23029f4
#
#
# Image 465: test/e2b2bb769a02252f
#
#
# Image 466: test/6eb2c1c2e058fd66
#
#
# Image 467: test/6894e498b8e1051a
#
#
# Image 468: test/7b4d8bac80d7fc1b
#
#
# Image 469: test/0d395241868daaca
#
#
# Image 470: test/2d778619f12c8aa1
#
#
# Image 471: test/909fdca8db79d695
#
#
# Image 472: test/a2c1d4542901af59
#
#
# Image 473: test/f8e16c37d86cf7f1
#
#
# Image 474: test/b038ae3586b13150
#
#
# Image 475: test/add49d324b6c6519
#
#
# Image 476: test/b93910f29c88135c
#
#
# Image 477: test/b920e2c13ee0a44a
#
#
# Image 478: test/70d82a0855d7db1e
#
#
# Image 479: test/d28e65cf1318a74f
#
#
# Image 480: test/bb8a221ad746a88d
#
#
# Image 481: test/0da08033b803bce3
#
#
# Image 482: test/75d2aff147a3d9b2
#
#
# Image 483: test/2714e794df83fdc7
#
#
# Image 484: test/9f5ce702bc30f4bb
#
#
# Image 485: test/a0646ac59cc509d3
#
#
# Image 486: test/1bb650046adf915c
#
#
# Image 487: test/2a948f136be07717
#
#
# Image 488: test/04f871899d640c8b
#
#
# Image 489: test/78efeeaaa1f0065a
#
#
# Image 490: test/f40d7cd71333a71c
#
#
# Image 491: test/3a3255202e45c0ff
#
#
# Image 492: test/8c8437145fedb582
#
#
# Image 493: test/430294ae5f3282de
#
#
# Image 494: test/d100c733d7af6ce3
#
#
# Image 495: test/e7c1cc990b7688bb
#
#
# Image 496: test/aa5b2f096711b5ab
#
#
# Image 497: test/6f0f875ad1cbf880
#
#
# Image 498: test/6015ddd1b7e7fd2a
#
#
# Image 499: test/4b1c82abd1b42f0f
#
#
# Image 500: test/5dbfb079d8db2c72
#
#
# Image 501: test/b3a94b0a61eb8e96
#
#
# Image 502: test/80f0f6792b623c85
#
#
# Image 503: test/055aa9c8e194b5a4
#
#
# Image 504: test/9dcd00b462e6bc66
#
#
# Image 505: test/33b065ff034fd571
#
#
# Image 506: test/f0181fa55953892d
#
#
# Image 507: test/4e030db7e2039d02
#
#
# Image 508: test/5a4fc14161a53bb4
#
#
# Image 509: test/f8117c37bd1081ad
#
#
# Image 510: test/a534ac6cddacaf4b
#
#
# Image 511: test/50175becd2637361
#
#
# Image 512: test/54f55316141b3f13
#
#
# Image 513: test/c4c12d3770377354
#
#
# Image 514: test/4bfa10cdb11c135c
#
#
# Image 515: test/ca41e3f9a6b5233c
#
#
# Image 516: test/3e05ba47acec4729
#
#
# Image 517: test/839bcdd34c9ed767
#
#
# Image 518: test/2da2c22f1bd3d367
#
#
# Image 519: test/b656d547bd619b38
#
#
# Image 520: test/9c19eb0c20e1b770
#
#
# Image 521: test/653f52da3e38c1a9
#
#
# Image 522: test/3bc4ad17a44d0074
#
#
# Image 523: test/bf34111353c70c97
#
#
# Image 524: test/025fa8b78ff0958f
#
#
# Image 525: test/9803d86a374c3cf0
#
#
# Image 526: test/0b680ddf8d7e4d9d
#
#
# Image 527: test/e118dbaffc6a2535
#
#
# Image 528: test/28b608c67cc7dd32
#
#
# Image 529: test/c81bbf1a921c3c75
#
#
# Image 530: test/52075e5165b6b32e
#
#
# Image 531: test/12d12e41c4eb84ea
#
#
# Image 532: test/f1ec2efa6c9ebb3c
#
#
# Image 533: test/885415d37f3bae3f
#
#
# Image 534: test/1cbac8c8f5628181
#
#
# Image 535: test/62083946d955bd41
#
#
# Image 536: test/92592e8d0c05155e
#
#
# Image 537: test/0eb9d25fd43c6f5a
#
#
# Image 538: test/ff2ba25a7fbd97ca
#
#
# Image 539: test/5b569c4cd6425b4c
#
#
# Image 540: test/35d39e56a62e22b0
#
#
# Image 541: test/6156bf8c83db2ead
#
#
# Image 542: test/d9dc72028cea6355
#
#
# Image 543: test/ce13aa8ee06831a4
#
#
# Image 544: test/3c692952609d0d4c
#
#
# Image 545: test/c9af4e4075ec2606
#
#
# Image 546: test/75f29ddc741b19e6
#
#
# Image 547: test/3ce69fe08c0998ad
#
#
# Image 548: test/8b5a953d2b8d565a
#
#
# Image 549: test/03d4045662b16f6d
#
#
# Image 550: test/059d775d79217de3
#
#
# Image 551: test/454c81bf4d562cd5
#
#
# Image 552: test/ba6871d2d3aa67f1
#
#
# Image 553: test/f0e3afe2b18ff87a
#
#
# Image 554: test/deecb9ce5d6a498e
#
#
# Image 555: test/8a2ddcd65ef8f584
#
#
# Image 556: test/ca9dd79d8681deff
#
#
# Image 557: test/480d07a18f2e3f0f
#
#
# Image 558: test/abf77b15e8687295
#
#
# Image 559: test/d633946227a4e10d
#
#
# Image 560: test/5eeaebae4384c26e
#
#
# Image 561: test/5076e481820efab8
#
#
# Image 562: test/f298f161ad5e6d1f
#
#
# Image 563: test/9d602ac6c337b9ca
#
#
# Image 564: test/15b4dfa4241f6f4d
#
#
# Image 565: test/505e61f233199d28
#
#
# Image 566: test/429e38b9f2af8a10
#
#
# Image 567: test/4541ece305ed5b49
#
#
# Image 568: test/f1c0a9d975281905
#
#
# Image 569: test/9fa5ec887d871fdf
#
#
# Image 570: test/0b16f41eb9184a10
#
#
# Image 571: test/6a90c427438ccbbb
#
#
# Image 572: test/e609bcb02b0936e1
#
#
# Image 573: test/feefa11fd6caa389
#
#
# Image 574: test/ecef2de6fd6884f7
#
#
# Image 575: test/b68fcdd3acd6248e
#
#
# Image 576: test/aa6eb929baa7cb33
#
#
# Image 577: test/ba317b86d783f1e3
#
#
# Image 578: test/0471147bc80704e1
#
#
# Image 579: test/b1d1b98d7db6224f
#
#
# Image 580: test/63f8fc8f39206ea5
#
#
# Image 581: test/b745f048554f3285
#
#
# Image 582: test/b6fa2ee605610e1c
#
#
# Image 583: test/0ff0afad0834e579
#
#
# Image 584: test/78b266b4c8ee0678
#
#
# Image 585: test/52ec964f940e5186
#
#
# Image 586: test/d29524c0cb12582d
#
#
# Image 587: test/d40df2c9c3502418
#
#
# Image 588: test/9b1e88d81173a268
#
#
# Image 589: test/3d3cae713593bab7
#
#
# Image 590: test/080c8490e5140cf8
#
#
# Image 591: test/699d4cca6bda3c71
#
#
# Image 592: test/0ea3ec2585a658e6
#
#
# Image 593: test/6cd83b4c764940ca
#
#
# Image 594: test/813a30568e82783b
#
#
# Image 595: test/0b37dd9ab94ef876
#
#
# Image 596: test/3d0a6b46bc03721f
#
#
# Image 597: test/86ef3f1ae6db2913
#
#
# Image 598: test/7892ad7113275c6b
#
#
# Image 599: test/8edb802ae1d0f85d
#
#
# Image 600: test/c201041917eeeb05
#
#
# Image 601: test/c23c52d28320655e
#
#
# Image 602: test/3691f16915123a65
#
#
# Image 603: test/f8852f023eea7189
#
#
# Image 604: test/f4cac328b1b203b2
#
#
# Image 605: test/1fc85ba4be8c662a
#
#
# Image 606: test/5e3d1ca2b836f7b5
#
#
# Image 607: test/41d9c2155033636b
#
#
# Image 608: test/beba299b2bbd6973
#
#
# Image 609: test/c70bd38fa9e4e35c
#
#
# Image 610: test/0ef513ae7cd8fd9e
#
#
# Image 611: test/bb4091a217cf8e4d
#
#
# Image 612: test/0951e7d928bb210f
#
#
# Image 613: test/367e80333bd99968
#
#
# Image 614: test/b6b63e891042d873
#
#
# Image 615: test/e70b0dfcdf3cfdb0
#
#
# Image 616: test/98562f5995ec185d
#
#
# Image 617: test/fc842f992135cad5
#
#
# Image 618: test/2abd4fbc00103007
#
#
# Image 619: test/b00e4d42ad78c8ca
#
#
# Image 620: test/fa9f65e945757609
#
#
# Image 621: test/d26f8ac3099cc847
#
#
# Image 622: test/97aa33f97c46c991
#
#
# Image 623: test/4c1d968b54357b6b
#
#
# Image 624: test/abaa71e962a5b716
#
#
# Image 625: test/281788974e5a023e
#
#
# Image 626: test/f485402474f566d4
#
#
# Image 627: test/ad4cb25c884b4024
#
#
# Image 628: test/735ee422374abd0b
#
#
# Image 629: test/d7dcd4367526d820
#
#
# Image 630: test/a6673f58d606426c
#
#
# Image 631: test/586696460ce68dd2
#
#
# Image 632: test/247182b61dab7c2c
#
#
# Image 633: test/781e1c6ecca5ec8f
#
#
# Image 634: test/5652662e6d5e7d91
#
#
# Image 635: test/a3228ea61b06bf4c
#
#
# Image 636: test/8b623c85c1bf0c23
#
#
# Image 637: test/e95476443b8738ce
#
#
# Image 638: test/cb06d69809d2f771
#
#
# Image 639: test/d81ac24258af2dc7
#
#
# Image 640: test/f52d5fee2c87c8bf
#
#
# Image 641: test/1f123d0bee392801
#
#
# Image 642: test/e1c29ed7ddf26bee
#
#
# Image 643: test/55ce25ec7e16fe8b
#
#
# Image 644: test/54a6f4906ceb62bc
#
#
# Image 645: test/de955f72012f617a
#
#
# Image 646: test/0264ebae1bc7ce1d
#
#
# Image 647: test/caf0c6c7ce77ceca
#
#
# Image 648: test/31b64dace9a9bb6c
#
#
# Image 649: test/e9850afbe9635fba
#
#
# Image 650: test/4d24a86d5f9ccc0f
#
#
# Image 651: test/b55fd80c75fbf599
#
#
# Image 652: test/aea6bda54be4d433
#
#
# Image 653: test/9dd7f1a00d2b03ab
#
#
# Image 654: test/ee37624f7a8e3969
#
#
# Image 655: test/234400819f72a80c
#
#
# Image 656: test/ec5e5279dd46450b
#
#
# Image 657: test/0467903150956d3e
#
#
# Image 658: test/58b64750c1f794eb
#
#
# Image 659: test/7331b81111aa40ba
#
#
# Image 660: test/71cd2134079e8318
#
#
# Image 661: test/ebeb8493f67b0f43
#
#
# Image 662: test/2dc382cb75851ef8
#
#
# Image 663: test/327da6c5607bf079
#
#
# Image 664: test/8c848df6ba50666e
#
#
# Image 665: test/44fd77264ea68644
#
#
# Image 666: test/0944f819041f0c01
#
#
# Image 667: test/42c9df2d7e393885
#
#
# Image 668: test/93793ce4b2ec036e
#
#
# Image 669: test/d8915543bf8ab788
#
#
# Image 670: test/adbdbfc08f08d2bb
#
#
# Image 671: test/84b9022642c6f564
#
#
# Image 672: test/198b6ca9c05a1677
#
#
# Image 673: test/5d0dfa7741dc9cc2
#
#
# Image 674: test/a6c80c27f4e551cd
#
#
# Image 675: test/c3fd9fc93ce0ef58
#
#
# Image 676: test/1c235f42099f9d7e
#
#
# Image 677: test/a9ea21dc99dffd4a
#
#
# Image 678: test/ce90f329d87bebc5
#
#
# Image 679: test/6012a35bfd61df5c
#
#
# Image 680: test/835f606f359f5a91
#
#
# Image 681: test/8771957ad490adf7
#
#
# Image 682: test/9a8ce7d701e93bf9
#
#
# Image 683: test/87a0c2780c393dd3
#
#
# Image 684: test/42ceae3b7c7640b8
#
#
# Image 685: test/7b9bc0193859f63a
#
#
# Image 686: test/925d79e8b7fdeb56
#
#
# Image 687: test/4f7b110ae85d0984
#
#
# Image 688: test/ad6aa1dd9f7083aa
#
#
# Image 689: test/afc290319e114f7b
#
#
# Image 690: test/85efafe09a153480
#
#
# Image 691: test/33fa9326dbeba19c
#
#
# Image 692: test/a25edb608ce6aa86
#
#
# Image 693: test/fb76edbe4b3e0a90
#
#
# Image 694: test/b67074144b115e74
#
#
# Image 695: test/4394fd19d29eaa73
#
#
# Image 696: test/72520502afe2869e
#
#
# Image 697: test/12cdc28f90d42611
#
#
# Image 698: test/53bb01b8b617b733
#
#
# Image 699: test/6d535a56aafa9ddd
#
#
# Image 700: test/397ddda4c38cc2b9
#
#
# Image 701: test/b3993f34705a5df0
#
#
# Image 702: test/f9354375a7289eae
#
#
# Image 703: test/fa9e6a9f3c9c179c
#
#
# Image 704: test/f568d20007ed0ffc
#
#
# Image 705: test/5343b64732666414
#
#
# Image 706: test/c02a562429546791
#
#
# Image 707: test/92c0f374bafbe9e7
#
#
# Image 708: test/1bf81f2479f17f6d
#
#
# Image 709: test/cbab6a7bf680f5f4
#
#
# Image 710: test/44209608a8b3ea6e
#
#
# Image 711: test/5d285b82c986c187
#
#
# Image 712: test/3ed3c286529cbe6e
#
#
# Image 713: test/c6435f07bb7d6c14
#
#
# Image 714: test/85e0e0c272a9cc33
#
#
# Image 715: test/6f270e11bd5ae9c9
#
#
# Image 716: test/37c72202188f2430
#
#
# Image 717: test/f4fc51872f862b7d
#
#
# Image 718: test/ad2488a24b363af4
#
#
# Image 719: test/f4700769d926756c
#
#
# Image 720: test/80dc9ebc4a33439f
#
#
# Image 721: test/f4c62ceff0bf812b
#
#
# Image 722: test/3b9d40f0513193dd
#
#
# Image 723: test/7a2dbf81a94599a5
#
#
# Image 724: test/f7a66c74595bbfd9
#
#
# Image 725: test/eb1cf0b1dc926352
#
#
# Image 726: test/5e42c08fa44cf1fa
#
#
# Image 727: test/448a3b6f36dcc893
#
#
# Image 728: test/3f37436d5bdc6275
#
#
# Image 729: test/f26bc234039fc148
#
#
# Image 730: test/5fabf373caa3511c
#
#
# Image 731: test/3e21073e910be54c
#
#
# Image 732: test/daf172c3db402302
#
#
# Image 733: test/1c0d24cd396a4055
#
#
# Image 734: test/f5fae0f966289f83
#
#
# Image 735: test/4c4f1bab04a9a3f9
#
#
# Image 736: test/01462ad475d84dc7
#
#
# Image 737: test/7c1c1c9bc56324d8
#
#
# Image 738: test/fa879bc2817a1bea
#
#
# Image 739: test/8f6e4c564f8fb824
#
#
# Image 740: test/2fb33af38966ed67
#
#
# Image 741: test/1684757ecdde3ffc
#
#
# Image 742: test/02394a3449862b85
#
#
# Image 743: test/9e4bed3a8edf36ef
#
#
# Image 744: test/b53562c14224ea8b
#
#
# Image 745: test/9efff7fa8b7f1cba
#
#
# Image 746: test/d7b3a8ec065d6c24
#
#
# Image 747: test/469a260d52786ae7
#
#
# Image 748: test/3c9fb4e572677982
#
#
# Image 749: test/43d582a028b0bebf
#
#
# Image 750: test/77ab9a66a7fb6b0e
#
#
# Image 751: test/776ea6710d045663
#
#
# Image 752: test/cd6b85df893c22fc
#
#
# Image 753: test/db75c53ddbace9dd
#
#
# Image 754: test/9edcebebe66ab9a1
#
#
# Image 755: test/67d2b6a46e54349a
#
#
# Image 756: test/94b5bbf01fe75e3e
#
#
# Image 757: test/8ac8b6cef31515f7
#
#
# Image 758: test/391fffff9889e31e
#
#
# Image 759: test/7e6a4163453f2aba
#
#
# Image 760: test/0b8442a9d20112b7
#
#
# Image 761: test/fafed2aae2ee3f5a
#
#
# Image 762: test/68307f7558af823b
#
#
# Image 763: test/c24cbf55576cd4fe
#
#
# Image 764: test/28dd46f142a42262
#
#
# Image 765: test/7d98c7ac25062f08
#
#
# Image 766: test/e49e87d5e3f7ff28
#
#
# Image 767: test/74df73e183d930a1
#
#
# Image 768: test/d190512ff494b71c
#
#
# Image 769: test/490c8bf9b24e9395
#
#
# Image 770: test/84e7de90027f1126
#
#
# Image 771: test/b2fc8e4fc72fd990
#
#
# Image 772: test/672e14d4f966ffcf
#
#
# Image 773: test/a65d2d855f81c96c
#
#
# Image 774: test/b14d2626a622082e
#
#
# Image 775: test/c799a2623ff55e19
#
#
# Image 776: test/0674d77e62802f1b
#
#
# Image 777: test/f2c7dedfc9279c7e
#
#
# Image 778: test/8818460cf879f9a5
#
#
# Image 779: test/ee8f6ed02cf711c8
#
#
# Image 780: test/7da862556ad2d7d0
#
#
# Image 781: test/3ca95255780f198f
#
#
# Image 782: test/be1af571afe48c72
#
#
# Image 783: test/16a618f9c5b0c3fb
#
#
# Image 784: test/0b776d266d5a1aa5
#
#
# Image 785: test/783b8174e2cbe886
#
#
# Image 786: test/b37ce7559a59c7e5
#
#
# Image 787: test/793c46914685184c
#
#
# Image 788: test/7e0594cfc87335bb
#
#
# Image 789: test/5f8c8145f6faf224
#
#
# Image 790: test/4054b53deae08c61
#
#
# Image 791: test/c54de2e3bc8aaa72
#
#
# Image 792: test/d435e03b2f2364c8
#
#
# Image 793: test/959f936543933399
#
#
# Image 794: test/56270f2c6df1c609
#
#
# Image 795: test/9937db9790e35b87
#
#
# Image 796: test/536af1db779abe87
#
#
# Image 797: test/2b53423be64d705e
#
#
# Image 798: test/6444a9bdfcca3f32
#
#
# Image 799: test/ab72f7e683601a55
#
#
# Image 800: test/88c56807c714a71f
#
#
# Image 801: test/fc4ae6f5a60d2484
#
#
# Image 802: test/9861622064bcf5a6
#
#
# Image 803: test/c0c36892321e1c29
#
#
# Image 804: test/60d4138b466d059f
#
#
# Image 805: test/ccf296e0d58ef7e6
#
#
# Image 806: test/09bdcb91ec620800
#
#
# Image 807: test/95e59623c871c809
#
#
# Image 808: test/456ee8a2bad82451
#
#
# Image 809: test/20b7af66e928d7c9
#
#
# Image 810: test/e6fa3322795b7657
#
#
# Image 811: test/9f23ec898669625f
#
#
# Image 812: test/753000a5adc0a523
#
#
# Image 813: test/11051240239ce83f
#
#
# Image 814: test/e563022367b0fe06
#
#
# Image 815: test/3b07e7c9cdd6d9e2
#
#
# Image 816: test/f20f3b42ab62a3fb
#
#
# Image 817: test/f9605eafbec86f29
#
#
# Image 818: test/1697b9774d92b62d
#
#
# Image 819: test/567fd51b4589d391
#
#
# Image 820: test/e35ae090d724c1ee
#
#
# Image 821: test/745dac0978281efd
#
#
# Image 822: test/1a43f299ea762e77
#
#
# Image 823: test/1e5b89ba812f2007
#
#
# Image 824: test/2654749385eccbd7
#
#
# Image 825: test/78a6df7e84d7e269
#
#
# Image 826: test/bcd2156fdf66103e
#
#
# Image 827: test/15dd606bdc7b862b
#
#
# Image 828: test/9fd03b8033577bac
#
#
# Image 829: test/622202e940d3308d
#
#
# Image 830: test/51c4ce2d1bf4d7af
#
#
# Image 831: test/052d46f94d922f49
#
#
# Image 832: test/7ce97122f0e27d28
#
#
# Image 833: test/f3d38a02ddca92ce
#
#
# Image 834: test/af9aad2bbb3a8ea7
#
#
# Image 835: test/7db4096e254bb105
#
#
# Image 836: test/1f92541b4f439e51
#
#
# Image 837: test/8dbc6f16dc2082aa
#
#
# Image 838: test/1517f32b03a8b35f
#
#
# Image 839: test/78e8079bd982f3f7
#
#
# Image 840: test/ae0ff5ea0d46aabb
#
#
# Image 841: test/f6b7b7669ac209a2
#
#
# Image 842: test/01abc3c637fc1609
#
#
# Image 843: test/acda8e968a4d7319
#
#
# Image 844: test/a44aa4be572b2256
#
#
# Image 845: test/e8d2686237861e46
#
#
# Image 846: test/78d03c12c935d6ab
#
#
# Image 847: test/1234cb08c1483f94
#
#
# Image 848: test/acd531be6fc706c8
#
#
# Image 849: test/984a61d6f6452c8b
#
#
# Image 850: test/967ef77b48a22bbb
#
#
# Image 851: test/e51f095410a04b37
#
#
# Image 852: test/74a2ae7fe25bad68
#
#
# Image 853: test/ffbc58b07824784e
#
#
# Image 854: test/4f2581cdbdaabac2
#
#
# Image 855: test/df09a37911ab2d2b
#
#
# Image 856: test/d76393249dfed2cc
#
#
# Image 857: test/8ba2912c6d17d64f
#
#
# Image 858: test/b0a659342871b0c0
#
#
# Image 859: test/4cc83d377cf1021b
#
#
# Image 860: test/55d6af701acb534c
#
#
# Image 861: test/e0726aee76e1bee6
#
#
# Image 862: test/fcf379aad09a34b0
#
#
# Image 863: test/1ac587be165a8606
#
#
# Image 864: test/a0e641c11392c4c7
#
#
# Image 865: test/f9ef5a0249851423
#
#
# Image 866: test/00ac3ac45fb6a7d4
#
#
# Image 867: test/934e3bde953a6f65
#
#
# Image 868: test/83b5fb611cb97c3e
#
#
# Image 869: test/012ecb88e569a3e7
#
#
# Image 870: test/147d3a4fbb5431e1
#
#
# Image 871: test/d7a0267c28cc4e79
#
#
# Image 872: test/ce4331ce64259239
#
#
# Image 873: test/16befd72198e5ee7
#
#
# Image 874: test/f84e05efb0ffc53a
#
#
# Image 875: test/704ae0ee2b02f8ae
#
#
# Image 876: test/bae9cfbf0a1fa695
#
#
# Image 877: test/acef88ab2025226c
#
#
# Image 878: test/ace746ce95431ffd
#
#
# Image 879: test/80771de293af8362
#
#
# Image 880: test/1ef48040995e65b7
#
#
# Image 881: test/a3a997196141f608
#
#
# Image 882: test/05ddac1ea53ebab1
#
#
# Image 883: test/13356ab3cb5d617d
#
#
# Image 884: test/9116c28e47a0f043
#
#
# Image 885: test/faf6422cbc145593
#
#
# Image 886: test/62a540c71e585ff6
#
#
# Image 887: test/ea5bf7e4e2d6887d
#
#
# Image 888: test/4b901b629d6bf04d
#
#
# Image 889: test/7aa9f132eba66f51
#
#
# Image 890: test/653e48c01f28169b
#
#
# Image 891: test/112a7e2b23abc1af
#
#
# Image 892: test/a7af6d69ff7616f5
#
#
# Image 893: test/617db912aadad450
#
#
# Image 894: test/1684878a21b5676c
#
#
# Image 895: test/f99057575e3b31ba
#
#
# Image 896: test/499192689ac368fc
#
#
# Image 897: test/fd5ab0036da245eb
#
#
# Image 898: test/6d2b9c39b5ed5ce4
#
#
# Image 899: test/d52e934bc80ffa0e
#
#
# Image 900: test/92c0a1e89a467815
#
#
# Image 901: test/ba348b190b11e58f
#
#
# Image 902: test/9490462343d2056b
#
#
# Image 903: test/3abd6446394be9b7
#
#
# Image 904: test/364c305cbcf8bac6
#
#
# Image 905: test/811f36e42195d1b9
#
#
# Image 906: test/408e6a6f9f0ab7f3
#
#
# Image 907: test/3cd741b8d45a2f53
#
#
# Image 908: test/1ede81394e48aa4e
#
#
# Image 909: test/6c82840646d74336
#
#
# Image 910: test/e58616a292dc4322
#
#
# Image 911: test/ae9d41ea5ccf5291
#
#
# Image 912: test/47edc9deaafcaef0
#
#
# Image 913: test/53210898d657d549
#
#
# Image 914: test/77f632ec95bf07da
#
#
# Image 915: test/cc95c3cb4f6b3e74
#
#
# Image 916: test/73152e33b94e9673
#
#
# Image 917: test/11f978ef11eb1024
#
#
# Image 918: test/c4ec797669eaeb0c
#
#
# Image 919: test/bf803ecc2adab840
#
#
# Image 920: test/ebccc845af78c962
#
#
# Image 921: test/a1a6468b7b666b1b
#
#
# Image 922: test/baabdb616da683f2
#
#
# Image 923: test/75293c83e6c5ca24
#
#
# Image 924: test/64bf904b8ecd157e
#
#
# Image 925: test/8ccd75c7bd8a4287
#
#
# Image 926: test/d85a059d048a8aa9
#
#
# Image 927: test/09430ad6e959b3e0
#
#
# Image 928: test/8778a3c219033997
#
#
# Image 929: test/11c148679e6d9ac5
#
#
# Image 930: test/bd4324ad1bb02191
#
#
# Image 931: test/f343cee1cb3a3826
#
#
# Image 932: test/63e77a7cc34a58f8
#
#
# Image 933: test/e92148cb276bde7b
#
#
# Image 934: test/ed199278b9e87476
#
#
# Image 935: test/e45b74e1069ec7c6
#
#
# Image 936: test/3c8116244f68283a
#
#
# Image 937: test/a29ce0b363f440f5
#
#
# Image 938: test/07d245a0f2de1b9a
#
#
# Image 939: test/e6c9c960350d2839
#
#
# Image 940: test/77610c816c6f34a7
#
#
# Image 941: test/fc38c95b141f33d1
#
#
# Image 942: test/ab4b7e39e4b20f99
#
#
# Image 943: test/dc5726d1977eb07b
#
#
# Image 944: test/1b32e788da559845
#
#
# Image 945: test/c3e41ef3b010f063
#
#
# Image 946: test/8c6ea225e96faf86
#
#
# Image 947: test/0c07862c8ac8835f
#
#
# Image 948: test/b6fe7a40d24be356
#
#
# Image 949: test/6b170f280fa50242
#
#
# Image 950: test/fbcb636a53e3fa28
#
#
# Image 951: test/cc7664bebea6e7ab
#
#
# Image 952: test/361c18bd16ea0a78
#
#
# Image 953: test/3f90d8155753ff39
#
#
# Image 954: test/5513de3c10ae65ae
#
#
# Image 955: test/8d68cb9d22cad12f
#
#
# Image 956: test/74256d0234e59145
#
#
# Image 957: test/c64845b617bd7f17
#
#
# Image 958: test/d02cbd6e02d40009
#
#
# Image 959: test/32254deda1fa8568
#
#
# Image 960: test/3fec48b329b26908
#
#
# Image 961: test/65ec1cde46fd03d9
#
#
# Image 962: test/5c955e3a7555aa23
#
#
# Image 963: test/e69d5fd0fdf74fbc
#
#
# Image 964: test/9c1b947e76e88e4c
#
#
# Image 965: test/12ab073ecf261b48
#
#
# Image 966: test/c710e24b4ab73c24
#
#
# Image 967: test/af0cad04f05549b3
#
#
# Image 968: test/8f6259ce5760ffcc
#
#
# Image 969: test/2a36113061b4e6eb
#
#
# Image 970: test/97af041a17f4a473
#
#
# Image 971: test/cd1339c041d5fc9d
#
#
# Image 972: test/360a7e322ce0bdab
#
#
# Image 973: test/5a7181ca067d16fe
#
#
# Image 974: test/0d4becbb921d522c
#
#
# Image 975: test/3ecc8dd591d2496d
#
#
# Image 976: test/7bf9c82292fa5f93
#
#
# Image 977: test/0b35fc31c3c6b33f
#
#
# Image 978: test/f85e447b48ecc509
#
#
# Image 979: test/2807437d7a3120c6
#
#
# Image 980: test/d5b0848802bdc67b
#
#
# Image 981: test/fa93a27e2acd6a3e
#
#
# Image 982: test/1fb794ab03ff15fb
#
#
# Image 983: test/158afe68201437a6
#
#
# Image 984: test/c1b6f9456508fe17
#
#
# Image 985: test/fd2937b2cd608754
#
#
# Image 986: test/d9c82f2be23ae7b8
#
#
# Image 987: test/5f0e980ee13e099f
#
#
# Image 988: test/bebc876ff1e883f2
#
#
# Image 989: test/4409d6a5cbc5b110
#
#
# Image 990: test/d10b41775cd58955
#
#
# Image 991: test/c50fd9dd89f7b200
#
#
# Image 992: test/890d41fde2503380
#
#
# Image 993: test/5305a594e5f192ae
#
#
# Image 994: test/c511f739667a9b9a
#
#
# Image 995: test/d8d3b805f9eb801b
#
#
# Image 996: test/7c0780f63122581e
#
#
# Image 997: test/05eea091c2b4cbaf
#
#
# Image 998: test/3a22e3fceeffc968
#
#
# Image 999: test/98f9bd50770d9d3d

# %%
import time

# 3: Make predictions.

start = time.time()

y_pred = model.predict(batch_images)

end = time.time()

print("Predicting 1000 images took {0} seconds".format(end-start))
# Out:
# Predicting 1000 images took 10.49495244026184 seconds

# %% [markdown]
# Now let's decode the raw predictions in `y_pred`.
#
# Had we created the model in 'inference' or 'inference_fast' mode, then the model's final layer would be a `DecodeDetections` layer and `y_pred` would already contain the decoded predictions, but since we created the model in 'training' mode, the model outputs raw predictions that still need to be decoded and filtered. This is what the `decode_detections()` function is for. It does exactly what the `DecodeDetections` layer would do, but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).
#
# `decode_detections()` with default argument values follows the procedure of the original SSD implementation: First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes, then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45, and out of what is left after that, the top 200 highest confidence boxes are returned. Those settings are for precision-recall scoring purposes though. In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5, since we're only interested in the very confident predictions.

# %%
# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.50,
                                   iou_threshold=0.45,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# %% [markdown]
# We made the predictions on the resized images, but we'd like to visualize the outcome on the original input images, so we'll convert the coordinates accordingly. Don't worry about that opaque `apply_inverse_transforms()` function below, in this simple case it just aplies `(* original_image_size / resized_image_size)` to the box coordinates.

# %%
# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
for i in range(len(y_pred_decoded_inv)):
  print("Image:", batch_filenames[i])
  print("Predicted boxes for image at index " + str(i) + ":")
  print('   class   conf xmin   ymin   xmax   ymax')
  print(y_pred_decoded_inv[i])
  print("\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Image: test/a69916691bc04b97
# Predicted boxes for image at index 278:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.88  70.    75.   724.   921.  ]]
#
#
# Image: test/a53d496a7a82b60f
# Predicted boxes for image at index 279:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.89 774.   180.   955.   712.  ]
#  [  1.     0.68  58.   202.   190.   584.  ]
#  [  1.     0.66 452.   192.   647.   661.  ]
#  [  1.     0.63 656.   200.   840.   710.  ]
#  [  1.     0.59 392.   199.   552.   634.  ]]
#
#
# Image: test/305eabd57a204cfc
# Predicted boxes for image at index 280:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.78 346.   117.   831.   400.  ]]
#
#
# Image: test/a1d70803ab8cd79f
# Predicted boxes for image at index 281:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.54 752.   -13.   950.   304.  ]
#  [  4.     0.99 152.    -8.   524.   297.  ]
#  [  4.     0.92 188.   315.   511.   597.  ]
#  [  4.     0.85 503.    -7.   799.   323.  ]
#  [  4.     0.82   6.    -4.   212.   302.  ]
#  [  4.     0.69  -4.   319.   205.   595.  ]
#  [  4.     0.68 480.   302.   827.   590.  ]
#  [  4.     0.6  731.   291.   945.   589.  ]]
#
#
# Image: test/eb1f31977655f5e9
# Predicted boxes for image at index 282:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.87  143.     32.   1024.    681.  ]]
#
#
# Image: test/5641455545707153
# Predicted boxes for image at index 283:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/abc8ffde8bfab388
# Predicted boxes for image at index 284:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.81 419.   596.   512.   675.  ]
#  [  1.     0.61 743.   175.   754.   190.  ]
#  [  1.     0.56 768.   173.   780.   190.  ]
#  [  1.     0.54 716.   175.   726.   189.  ]
#  [  4.     0.53 647.   573.   787.   671.  ]]
#
#
# Image: test/52b8428114aab942
# Predicted boxes for image at index 285:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.    1.    4.  120.  669. 1020.]]
#
#
# Image: test/62c75e993beb5e37
# Predicted boxes for image at index 286:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.68 475.    96.   746.   623.  ]
#  [  1.     0.5  258.   123.   593.   633.  ]]
#
#
# Image: test/ac2fbac535c39792
# Predicted boxes for image at index 287:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.92 103.   104.   421.   834.  ]
#  [  2.     0.63 305.   231.   496.   779.  ]]
#
#
# Image: test/df95ab534bab2bc9
# Predicted boxes for image at index 288:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.89 529.   139.   943.   638.  ]]
#
#
# Image: test/36510c238ed56073
# Predicted boxes for image at index 289:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.63  45.   147.   584.   990.  ]]
#
#
# Image: test/03a80d9b80d8082b
# Predicted boxes for image at index 290:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.56 199.   -23.   462.   968.  ]
#  [  4.     0.56 201.   -48.   451.   957.  ]]
#
#
# Image: test/f3e534908176f8f6
# Predicted boxes for image at index 291:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.      0.77  203.      6.   1023.    675.  ]]
#
#
# Image: test/938bc5c0caa8055a
# Predicted boxes for image at index 292:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/dd77d31dc3ebfd5a
# Predicted boxes for image at index 293:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.81   12.     -1.    719.   1021.  ]]
#
#
# Image: test/9350f76d7a252e61
# Predicted boxes for image at index 294:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.91  133.     -3.   1000.    674.  ]
#  [   1.      0.8   263.    211.    382.    383.  ]
#  [   2.      0.65  143.    217.    359.    607.  ]]
#
#
# Image: test/17335464bad50052
# Predicted boxes for image at index 295:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.67 242.   370.   422.   678.  ]
#  [  3.     0.53 332.   562.   571.   793.  ]
#  [  4.     0.57 343.   514.   652.   952.  ]]
#
#
# Image: test/43b3da44901f1303
# Predicted boxes for image at index 296:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.      0.88   31.     25.   1030.   1006.  ]]
#
#
# Image: test/0159c0e9e26e49ce
# Predicted boxes for image at index 297:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.63 214.    76.   742.   644.  ]]
#
#
# Image: test/4218dcab8d1c023b
# Predicted boxes for image at index 298:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.77  25.    -0.   294.   698.  ]]
#
#
# Image: test/30a546b433144732
# Predicted boxes for image at index 299:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.77  62.    76.   583.   767.  ]]
#
#
# Image: test/7a3e6fea7b46e1ac
# Predicted boxes for image at index 300:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.99 181.   212.   516.   788.  ]]
#
#
# Image: test/bb2d37522e52f6fc
# Predicted boxes for image at index 301:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.97 169.    -4.   944.   681.  ]]
#
#
# Image: test/62c593f035946ebc
# Predicted boxes for image at index 302:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.73  242.     10.    793.   1023.  ]]
#
#
# Image: test/df06bb439195c017
# Predicted boxes for image at index 303:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.94 257.   130.   571.   519.  ]]
#
#
# Image: test/7c6b553e4cfbcc45
# Predicted boxes for image at index 304:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.97   94.     15.    883.   1013.  ]]
#
#
# Image: test/5c3b3dd1f4c4a681
# Predicted boxes for image at index 305:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.66 585.    57.   658.   170.  ]]
#
#
# Image: test/29e19e55d551a520
# Predicted boxes for image at index 306:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.61  -0.    98.   308.   735.  ]]
#
#
# Image: test/5bb5c07954c50aa9
# Predicted boxes for image at index 307:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98 166.    27.   684.   818.  ]]
#
#
# Image: test/ebb059d8ef36c089
# Predicted boxes for image at index 308:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.8   45.   111.   268.   691.  ]
#  [  2.     0.59  51.   166.   998.   688.  ]]
#
#
# Image: test/26eba60bf2828382
# Predicted boxes for image at index 309:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.81  19.    80.   593.   852.  ]]
#
#
# Image: test/64055a119a99ff60
# Predicted boxes for image at index 310:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 246.    88.   842.   640.  ]]
#
#
# Image: test/2225b2c55ccdb2d6
# Predicted boxes for image at index 311:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.83    6.     60.    759.   1019.  ]]
#
#
# Image: test/1a30bc4b72bf51f2
# Predicted boxes for image at index 312:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.96 203.    57.   687.   805.  ]]
#
#
# Image: test/b101309cbb503113
# Predicted boxes for image at index 313:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.92   94.    -10.    425.    906.  ]
#  [   4.      0.82  198.    708.    339.   1002.  ]]
#
#
# Image: test/65e18e3f65bf89ae
# Predicted boxes for image at index 314:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.      0.69    2.      9.    687.   1011.  ]]
#
#
# Image: test/b34d853c78cac35a
# Predicted boxes for image at index 315:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.79   50.    114.    825.   1025.  ]]
#
#
# Image: test/483b51b90bef9895
# Predicted boxes for image at index 316:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.65  77.    19.   838.   765.  ]]
#
#
# Image: test/c60e4afce27cf5dd
# Predicted boxes for image at index 317:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.86 506.   313.   670.   630.  ]
#  [  3.     0.74   4.   700.   120.   970.  ]]
#
#
# Image: test/fe9d080481f6d3d7
# Predicted boxes for image at index 318:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.87 198.   300.   376.   424.  ]
#  [  3.     0.67 180.   124.   303.   247.  ]
#  [  3.     0.52 512.   299.   633.   429.  ]]
#
#
# Image: test/d02ec3c8b01563e0
# Predicted boxes for image at index 319:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.71 762.   307.   840.   587.  ]
#  [  3.     0.69 563.   294.   662.   549.  ]
#  [  3.     0.61 815.   317.   894.   586.  ]
#  [  3.     0.57 102.   288.   186.   589.  ]]
#
#
# Image: test/f6152a8ba6e644b1
# Predicted boxes for image at index 320:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.96 206.   118.   550.   592.  ]
#  [  2.     0.86 274.   504.   486.   674.  ]
#  [  2.     0.78 524.   489.   747.   672.  ]]
#
#
# Image: test/dc9da4e096dd0813
# Predicted boxes for image at index 321:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.8  670.   391.   880.   678.  ]
#  [  3.     0.58 587.   407.   758.   655.  ]]
#
#
# Image: test/359d9791156e4dbc
# Predicted boxes for image at index 322:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.88 510.   175.   912.   649.  ]
#  [  2.     0.81  -5.   155.   299.   639.  ]]
#
#
# Image: test/ffede35b67aab7d2
# Predicted boxes for image at index 323:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.61  12.   -28.   277.   596.  ]]
#
#
# Image: test/c9d101a0d3c33deb
# Predicted boxes for image at index 324:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.76   2.    -4.   300.   897.  ]
#  [  3.     0.52 348.   161.   550.   719.  ]
#  [  4.     0.5  347.   165.   553.   713.  ]]
#
#
# Image: test/36798fac28352b1c
# Predicted boxes for image at index 325:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.99  278.    101.    745.    634.  ]
#  [   1.      0.89   13.     76.    317.    653.  ]
#  [   1.      0.66  828.    211.   1006.    488.  ]]
#
#
# Image: test/5621ee64f384470c
# Predicted boxes for image at index 326:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.87  71.     1.   196.   310.  ]]
#
#
# Image: test/53ed581dda907c8b
# Predicted boxes for image at index 327:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.83 390.    65.   596.   647.  ]]
#
#
# Image: test/824952209908f287
# Predicted boxes for image at index 328:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     1.   -10.   258.   333.   636.  ]
#  [  1.     0.86 355.    35.   844.   607.  ]]
#
#
# Image: test/d1266f7cd519f745
# Predicted boxes for image at index 329:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.75  61.     9.   740.   572.  ]]
#
#
# Image: test/2d5fecf5315419cc
# Predicted boxes for image at index 330:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.96 153.   176.   334.   560.  ]]
#
#
# Image: test/e0c3ebfc6b4c0f90
# Predicted boxes for image at index 331:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.72  81.    52.   946.   497.  ]
#  [  3.     0.52 225.    78.   645.   394.  ]]
#
#
# Image: test/3e5f0e25329926f4
# Predicted boxes for image at index 332:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.86 308.   285.   575.   473.  ]]
#
#
# Image: test/ba0498ce53cb483f
# Predicted boxes for image at index 333:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.72 362.    80.   658.   648.  ]]
#
#
# Image: test/531c8d764432ed50
# Predicted boxes for image at index 334:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98  27.   190.   337.   925.  ]
#  [  2.     0.89 239.    41.   591.   943.  ]]
#
#
# Image: test/c9c1813883ee088c
# Predicted boxes for image at index 335:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.81 259.    74.   487.   893.  ]]
#
#
# Image: test/29b0b6fdac6ff269
# Predicted boxes for image at index 336:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.67 118.    28.   818.   676.  ]]
#
#
# Image: test/a1f38be2905908b0
# Predicted boxes for image at index 337:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.63 104.    65.   870.   686.  ]]
#
#
# Image: test/b8bc01d577165acc
# Predicted boxes for image at index 338:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.82 -17.    85.   537.   632.  ]
#  [  2.     0.75 447.     2.   922.   603.  ]]
#
#
# Image: test/3767b86cb78bef13
# Predicted boxes for image at index 339:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.71 159.   201.   500.   684.  ]]
#
#
# Image: test/6f786fcf4f2eb451
# Predicted boxes for image at index 340:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.77 104.     0.   796.   753.  ]
#  [  3.     0.96 228.   399.   740.   720.  ]]
#
#
# Image: test/4d95b874bc7801ef
# Predicted boxes for image at index 341:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.97 368.   468.   667.   941.  ]]
#
#
# Image: test/a19cad70e397a8c1
# Predicted boxes for image at index 342:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.92 417.   -48.   754.   982.  ]]
#
#
# Image: test/e84f6994de427de9
# Predicted boxes for image at index 343:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.78 142.    -7.   361.   529.  ]
#  [  2.     0.54 297.    -5.   687.   658.  ]
#  [  3.     0.51  72.     7.   170.   276.  ]
#  [  3.     0.5  634.    27.   810.   210.  ]
#  [  4.     0.58  -0.   407.   247.   675.  ]]
#
#
# Image: test/a5510558f0dc5589
# Predicted boxes for image at index 344:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.61   3.   184.   643.   647.  ]]
#
#
# Image: test/5f9eec8ea0109185
# Predicted boxes for image at index 345:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.57 402.    32.   752.   643.  ]]
#
#
# Image: test/5982b76dff9699d1
# Predicted boxes for image at index 346:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.65   2.   619.   213.   933.  ]]
#
#
# Image: test/caadf773368039a2
# Predicted boxes for image at index 347:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.97   0.   216.   306.   634.  ]
#  [  1.     0.79 675.   143.   872.   592.  ]
#  [  1.     0.57 808.   109.   965.   640.  ]
#  [  1.     0.56  -7.   206.   121.   466.  ]
#  [  2.     0.8  541.   448.   838.   672.  ]
#  [  2.     0.54  13.   121.   136.   246.  ]
#  [  4.     0.52 662.    92.   827.   290.  ]]
#
#
# Image: test/77b3a7413941c16d
# Predicted boxes for image at index 348:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.97 122.   137.   535.   828.  ]]
#
#
# Image: test/9c68351d686cbf3d
# Predicted boxes for image at index 349:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.93 190.    -7.   764.   999.  ]
#  [  2.     0.59  14.   143.   339.   975.  ]]
#
#
# Image: test/f072464df71208e8
# Predicted boxes for image at index 350:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.61 178.    10.   806.   596.  ]
#  [  3.     0.51 183.     4.   800.   608.  ]]
#
#
# Image: test/1082cbe62ac8fe05
# Predicted boxes for image at index 351:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.73 105.    80.   457.   974.  ]
#  [  2.     0.54 266.   157.   495.   947.  ]
#  [  4.     0.67 571.   136.   797.   933.  ]]
#
#
# Image: test/7425d828852c6e05
# Predicted boxes for image at index 352:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.91 104.    71.   724.   679.  ]]
#
#
# Image: test/f24b6d2e4a6e3467
# Predicted boxes for image at index 353:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.72 103.   -20.   491.   451.  ]]
#
#
# Image: test/41d4bdc67ce4d1c6
# Predicted boxes for image at index 354:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.92   3.   145.   335.   717.  ]
#  [  2.     0.74 632.   218.   966.   551.  ]]
#
#
# Image: test/a853826ece613fda
# Predicted boxes for image at index 355:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.71 272.    53.   795.   635.  ]
#  [  3.     0.52 890.   202.   962.   257.  ]]
#
#
# Image: test/27c6327dec331040
# Predicted boxes for image at index 356:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.97   59.      5.    587.   1000.  ]]
#
#
# Image: test/1aa10fee2d5f8aa0
# Predicted boxes for image at index 357:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.76 459.    98.   673.   467.  ]]
#
#
# Image: test/65433c5a09f63551
# Predicted boxes for image at index 358:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.64  31.   380.   186.   598.  ]]
#
#
# Image: test/a7c86c20e06c095d
# Predicted boxes for image at index 359:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.93 404.   300.   582.   562.  ]]
#
#
# Image: test/a4442587774e19c9
# Predicted boxes for image at index 360:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 189.    23.   520.   612.  ]
#  [  1.     0.52 731.    94.   830.   256.  ]
#  [  2.     0.65 789.    74.   950.   396.  ]
#  [  4.     0.79  29.   160.   244.   605.  ]]
#
#
# Image: test/4d1aa2e121977f7c
# Predicted boxes for image at index 361:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.71 138.    31.   955.   676.  ]]
#
#
# Image: test/ac70f58bbb130fc3
# Predicted boxes for image at index 362:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.69  102.    166.    639.   1022.  ]]
#
#
# Image: test/0a6c0209c9aa3363
# Predicted boxes for image at index 363:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.98   -3.    352.    264.    721.  ]
#  [   1.      0.88  916.    424.   1003.    736.  ]
#  [   1.      0.85  517.    419.    610.    743.  ]
#  [   1.      0.73  801.    436.    908.    747.  ]
#  [   1.      0.73  578.    443.    718.    765.  ]
#  [   1.      0.66  714.    457.    831.    761.  ]
#  [   2.      0.9   232.    441.    381.    759.  ]
#  [   2.      0.83  404.    432.    505.    710.  ]]
#
#
# Image: test/e3838188cb36822b
# Predicted boxes for image at index 364:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/62b53b417b02e75c
# Predicted boxes for image at index 365:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.78  94.   -31.   529.   949.  ]
#  [  2.     0.53   3.    -5.   203.   681.  ]
#  [  4.     0.56  -9.   -28.   199.   628.  ]]
#
#
# Image: test/96d40d1cc61b5212
# Predicted boxes for image at index 366:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/676bec8ddc1c130d
# Predicted boxes for image at index 367:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.94 237.   219.   662.   661.  ]
#  [  4.     0.56 589.   230.   890.   644.  ]]
#
#
# Image: test/05b802246e18c682
# Predicted boxes for image at index 368:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.      0.65   42.    308.    675.   1022.  ]]
#
#
# Image: test/05863d03cc53695d
# Predicted boxes for image at index 369:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/d9047db41f6d69c8
# Predicted boxes for image at index 370:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.53 264.   236.   430.   542.  ]
#  [  4.     0.53 736.   359.   853.   478.  ]]
#
#
# Image: test/f08e99e211ddaf27
# Predicted boxes for image at index 371:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/8acc974557f6c888
# Predicted boxes for image at index 372:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.65 623.   226.   865.   721.  ]]
#
#
# Image: test/c84de15018e0cfe4
# Predicted boxes for image at index 373:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.77  51.    94.   396.   680.  ]]
#
#
# Image: test/8f47e94ffe35c08b
# Predicted boxes for image at index 374:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.55 434.   233.   513.   348.  ]]
#
#
# Image: test/d38d644842b0b3b0
# Predicted boxes for image at index 375:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.93 276.    -2.   684.   574.  ]]
#
#
# Image: test/86f725d6e39799eb
# Predicted boxes for image at index 376:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.58 110.    45.   554.   971.  ]]
#
#
# Image: test/aebfe27dc4b1b3ba
# Predicted boxes for image at index 377:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.7  483.    33.   659.   394.  ]
#  [  3.     0.77 384.   194.   629.   847.  ]
#  [  4.     0.9  184.   487.   352.   966.  ]
#  [  4.     0.86 324.   501.   491.   976.  ]
#  [  4.     0.58 213.     0.   502.   636.  ]]
#
#
# Image: test/e442b41a459d6695
# Predicted boxes for image at index 378:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.91    2.     57.    725.   1011.  ]]
#
#
# Image: test/073b3367710e71be
# Predicted boxes for image at index 379:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.75   19.      7.    670.   1026.  ]]
#
#
# Image: test/590f9b00905fe5d8
# Predicted boxes for image at index 380:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.58 349.    94.   615.   781.  ]]
#
#
# Image: test/c6737278e2845421
# Predicted boxes for image at index 381:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.63 302.   219.   452.   698.  ]
#  [  4.     0.63 127.   580.   296.   943.  ]]
#
#
# Image: test/492b6010e13e51b7
# Predicted boxes for image at index 382:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.56 243.    22.   839.   565.  ]]
#
#
# Image: test/18b4ed30f44419b5
# Predicted boxes for image at index 383:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/22902f98b24b705c
# Predicted boxes for image at index 384:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.97 470.   222.   594.   464.  ]
#  [  1.     0.55 568.   243.   656.   477.  ]]
#
#
# Image: test/d171c781cfea9d98
# Predicted boxes for image at index 385:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98  36.    -0.   609.   899.  ]]
#
#
# Image: test/f45b90353ea21448
# Predicted boxes for image at index 386:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.66  57.   117.   872.   757.  ]]
#
#
# Image: test/cb234218c5ce37d7
# Predicted boxes for image at index 387:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.55 137.   -20.   460.   966.  ]]
#
#
# Image: test/0bee6b7507845d34
# Predicted boxes for image at index 388:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.72 635.   214.   924.   647.  ]
#  [  1.     0.58  -9.   195.   348.   647.  ]
#  [  3.     0.63 521.    51.   621.   184.  ]
#  [  3.     0.51  -5.   195.   351.   658.  ]
#  [  4.     0.67 277.    77.   439.   341.  ]]
#
#
# Image: test/de8ede02f0a7d4c8
# Predicted boxes for image at index 389:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.72 500.   -26.   876.   534.  ]]
#
#
# Image: test/72a6bae165a0b0cd
# Predicted boxes for image at index 390:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/373c48cabfb0168e
# Predicted boxes for image at index 391:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.83 338.   127.   693.   939.  ]]
#
#
# Image: test/2a28eabff35bd2f7
# Predicted boxes for image at index 392:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.74 796.   225.   889.   322.  ]
#  [  2.     0.96 475.    91.   939.   640.  ]
#  [  2.     0.7  226.    36.   553.   630.  ]
#  [  2.     0.67  13.    22.   228.   567.  ]]
#
#
# Image: test/e84ae19f54c41c00
# Predicted boxes for image at index 393:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.62   1.    65.   979.   758.  ]]
#
#
# Image: test/a8eb1407e107144f
# Predicted boxes for image at index 394:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.85 538.    82.   641.   248.  ]
#  [  1.     0.55   3.   102.   117.   237.  ]]
#
#
# Image: test/96df64f2c1aaecef
# Predicted boxes for image at index 395:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.83  34.    33.   565.   939.  ]]
#
#
# Image: test/10cdaca6d67dd98c
# Predicted boxes for image at index 396:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 434.   106.   644.   553.  ]
#  [  1.     0.82 232.   170.   446.   509.  ]]
#
#
# Image: test/e1e05eb06327f89f
# Predicted boxes for image at index 397:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.78 726.   211.   883.   685.  ]
#  [  1.     0.51 668.   232.   783.   689.  ]
#  [  3.     0.51 165.   210.   301.   668.  ]]
#
#
# Image: test/ae502c37b26c72f8
# Predicted boxes for image at index 398:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.98   61.     45.    809.    767.  ]
#  [   1.      0.73  900.    315.   1001.    623.  ]]
#
#
# Image: test/246840056187710d
# Predicted boxes for image at index 399:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.91  67.     1.   983.   773.  ]]
#
#
# Image: test/00b96ff2060fcfa2
# Predicted boxes for image at index 400:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.78 601.   -19.   813.   530.  ]]
#
#
# Image: test/d9400411a6fd90f7
# Predicted boxes for image at index 401:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.72 104.    25.   700.   879.  ]]
#
#
# Image: test/0eed10a64602dccf
# Predicted boxes for image at index 402:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/3974f503366bcd92
# Predicted boxes for image at index 403:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.55 832.   133.   939.   399.  ]]
#
#
# Image: test/ee03738597984544
# Predicted boxes for image at index 404:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/9553b9608577b74b
# Predicted boxes for image at index 405:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.87   52.    100.    694.   1015.  ]]
#
#
# Image: test/ce1f2e2a166d185a
# Predicted boxes for image at index 406:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.99 265.   113.   734.   897.  ]]
#
#
# Image: test/5e106cd106e265d9
# Predicted boxes for image at index 407:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.94 -11.   140.   314.   617.  ]
#  [  1.     0.84 421.   171.   854.   626.  ]]
#
#
# Image: test/1d8d480ee9334149
# Predicted boxes for image at index 408:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.77  414.    133.    720.    671.  ]
#  [   1.      0.74  857.    193.   1002.    468.  ]
#  [   3.      0.5   480.    273.    872.    701.  ]]
#
#
# Image: test/b9b426c5e422455e
# Predicted boxes for image at index 409:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.65   54.    114.    613.   1015.  ]]
#
#
# Image: test/3042b8ad77c737f3
# Predicted boxes for image at index 410:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.92 170.    27.   286.   253.  ]
#  [  1.     0.87 453.   250.   741.   525.  ]
#  [  1.     0.67 324.    36.   440.   254.  ]
#  [  3.     0.64 576.    37.   702.   267.  ]]
#
#
# Image: test/6bbb2094073681dd
# Predicted boxes for image at index 411:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.96 166.    43.   632.   763.  ]]
#
#
# Image: test/a7cdac6d48c31a49
# Predicted boxes for image at index 412:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99  50.    13.   531.   738.  ]
#  [  2.     0.68 467.    98.   834.   745.  ]
#  [  3.     0.58 818.   506.   944.   750.  ]]
#
#
# Image: test/0f050297e01c8c08
# Predicted boxes for image at index 413:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.95 308.   145.   621.   599.  ]
#  [  3.     0.99  38.   289.   324.   641.  ]
#  [  3.     0.78 879.    49.   995.   282.  ]
#  [  3.     0.74 598.   113.   903.   585.  ]]
#
#
# Image: test/627ceafe0ac6eef7
# Predicted boxes for image at index 414:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.56 635.   155.   850.   779.  ]]
#
#
# Image: test/fea1c0d93e92fb61
# Predicted boxes for image at index 415:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.89 456.   347.   899.   970.  ]]
#
#
# Image: test/3985377d4e892b37
# Predicted boxes for image at index 416:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.96  165.    131.    597.   1018.  ]
#  [   1.      0.94   49.    194.    345.    969.  ]]
#
#
# Image: test/ed3c874c062479aa
# Predicted boxes for image at index 417:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.87 122.    97.   236.   330.  ]
#  [  2.     0.85 758.   115.   880.   274.  ]
#  [  2.     0.8  659.   114.   752.   325.  ]
#  [  2.     0.73 401.   123.   599.   580.  ]
#  [  2.     0.7  296.   110.   447.   584.  ]
#  [  2.     0.69 133.   126.   339.   587.  ]
#  [  2.     0.68 668.   199.   902.   587.  ]
#  [  2.     0.65 805.   156.   967.   573.  ]
#  [  2.     0.64 542.   120.   700.   573.  ]
#  [  2.     0.51   4.   128.   169.   595.  ]]
#
#
# Image: test/b5cfbb6af18c27da
# Predicted boxes for image at index 418:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.83 115.    77.   809.   917.  ]]
#
#
# Image: test/6b6a9e01ab46404c
# Predicted boxes for image at index 419:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.57  938.    386.   1005.    485.  ]
#  [   3.      0.95  833.    403.    962.    643.  ]]
#
#
# Image: test/138a92a78193bb7b
# Predicted boxes for image at index 420:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/6cc42293ce185c89
# Predicted boxes for image at index 421:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.97  10.   219.   308.   563.  ]
#  [  1.     0.96 244.   209.   608.   542.  ]
#  [  1.     0.83 696.   231.   993.   459.  ]]
#
#
# Image: test/69dbd2db13bd1994
# Predicted boxes for image at index 422:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.62 201.    12.   808.   726.  ]]
#
#
# Image: test/1658ee700cc5cf6e
# Predicted boxes for image at index 423:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/404ebe15c0979189
# Predicted boxes for image at index 424:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.88 138.   225.   467.   693.  ]
#  [  4.     0.6  516.    78.   846.   685.  ]]
#
#
# Image: test/150a2c9c7f6d43e7
# Predicted boxes for image at index 425:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.98 512.   174.   835.   627.  ]
#  [  3.     0.56 283.    96.   552.   622.  ]
#  [  4.     0.91  66.   392.   211.   602.  ]
#  [  4.     0.81 841.   409.   998.   629.  ]]
#
#
# Image: test/5c5e755aef2f2366
# Predicted boxes for image at index 426:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/b4637efd9aeff4b8
# Predicted boxes for image at index 427:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98 115.     3.   904.   672.  ]]
#
#
# Image: test/7151187b70a7a9a0
# Predicted boxes for image at index 428:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/c6888f370f5469f4
# Predicted boxes for image at index 429:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.81 867.   313.   997.   472.  ]
#  [  1.     0.56 145.    30.   206.   131.  ]
#  [  1.     0.55 113.    33.   176.   136.  ]
#  [  1.     0.53 778.   227.   879.   481.  ]
#  [  2.     0.69 541.    95.   640.   211.  ]]
#
#
# Image: test/c10c10eecc532b24
# Predicted boxes for image at index 430:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.66  53.    65.   633.   781.  ]]
#
#
# Image: test/48ea1aece690023f
# Predicted boxes for image at index 431:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.      0.71   74.     20.    749.   1010.  ]]
#
#
# Image: test/c5a12ff9a573f5c8
# Predicted boxes for image at index 432:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.      0.62   85.     23.    615.   1003.  ]]
#
#
# Image: test/9e157c70d7a40947
# Predicted boxes for image at index 433:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.93 475.   229.   633.   643.  ]
#  [  1.     0.82 235.   263.   415.   641.  ]
#  [  1.     0.81 630.   285.   725.   626.  ]
#  [  1.     0.56 779.   308.   900.   669.  ]
#  [  1.     0.53 469.   287.   538.   560.  ]]
#
#
# Image: test/808bfc45836b5783
# Predicted boxes for image at index 434:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98  31.    26.   904.   676.  ]]
#
#
# Image: test/6c07560197c23c6c
# Predicted boxes for image at index 435:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.56 265.   235.   525.   468.  ]
#  [  3.     0.78  11.    90.   123.   284.  ]
#  [  3.     0.54 247.   220.   511.   455.  ]]
#
#
# Image: test/57a7254dcf8e0b18
# Predicted boxes for image at index 436:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.7     4.    -32.    253.    662.  ]
#  [   3.      0.99  666.     93.    873.    527.  ]
#  [   3.      0.95  437.     80.    647.    566.  ]
#  [   3.      0.6   903.    136.   1005.    537.  ]]
#
#
# Image: test/27013b446c95c95b
# Predicted boxes for image at index 437:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 318.   149.   672.   654.  ]
#  [  1.     0.96 642.    80.   959.   656.  ]
#  [  1.     0.79  63.   101.   400.   667.  ]]
#
#
# Image: test/c91e1f23514504a2
# Predicted boxes for image at index 438:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.76 260.    44.   690.   748.  ]]
#
#
# Image: test/4213f70e782c6d9e
# Predicted boxes for image at index 439:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.82 127.    19.   990.   775.  ]
#  [  1.     0.81   6.   -18.   535.   760.  ]]
#
#
# Image: test/3b3d545280602f3b
# Predicted boxes for image at index 440:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/97bd4d44d3eba27d
# Predicted boxes for image at index 441:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 320.    -5.   684.   606.  ]]
#
#
# Image: test/e4af06d7c8b74d86
# Predicted boxes for image at index 442:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.87 256.    27.   640.   665.  ]
#  [  1.     0.76   2.    48.   158.   532.  ]]
#
#
# Image: test/d0f5e478b3956b0a
# Predicted boxes for image at index 443:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/717eb8ceac99a2cc
# Predicted boxes for image at index 444:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.84   37.     49.    722.   1017.  ]]
#
#
# Image: test/68ff0b39dbc6574b
# Predicted boxes for image at index 445:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.    1.   33.  101.  704. 1024.]]
#
#
# Image: test/7efa491b25b5dd28
# Predicted boxes for image at index 446:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.89 306.   201.   411.   469.  ]
#  [  1.     0.73 666.   160.   776.   383.  ]
#  [  1.     0.55 724.   161.   866.   490.  ]
#  [  2.     0.82 449.    41.   620.   559.  ]]
#
#
# Image: test/ef98838a8b76bbad
# Predicted boxes for image at index 447:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.95 456.    87.   939.   731.  ]
#  [  2.     0.79  25.   -11.   527.   766.  ]]
#
#
# Image: test/84152b39e3c3f2aa
# Predicted boxes for image at index 448:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.87  17.     8.   721.   979.  ]]
#
#
# Image: test/3336248fb42c5466
# Predicted boxes for image at index 449:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.77 657.   247.   790.   595.  ]
#  [  3.     0.81 781.   282.   856.   400.  ]]
#
#
# Image: test/a9ece2ef7f0bb1cd
# Predicted boxes for image at index 450:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.54 704.   -11.   900.   643.  ]]
#
#
# Image: test/82660e16ff8b11ea
# Predicted boxes for image at index 451:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.    0.8 367.  302.  662.  554. ]]
#
#
# Image: test/6a30a282543fd175
# Predicted boxes for image at index 452:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.96 710.   259.   969.   742.  ]
#  [  1.     0.94 718.   112.   954.   490.  ]
#  [  1.     0.92 203.   262.   500.   739.  ]
#  [  1.     0.52 318.    88.   509.   483.  ]
#  [  1.     0.5   -9.   255.   227.   751.  ]
#  [  2.     0.81 449.   275.   714.   726.  ]
#  [  2.     0.73 185.   174.   342.   475.  ]
#  [  2.     0.66 487.   140.   661.   467.  ]
#  [  2.     0.61  46.   157.   210.   438.  ]]
#
#
# Image: test/3516ffd0eb5ba846
# Predicted boxes for image at index 453:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.9   35.   127.   237.   533.  ]
#  [  1.     0.81 291.   278.   581.   641.  ]
#  [  2.     0.66 365.   110.   540.   490.  ]]
#
#
# Image: test/dd73e8250e032d35
# Predicted boxes for image at index 454:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98   7.   114.   654.   996.  ]]
#
#
# Image: test/c09a6e516e6130a9
# Predicted boxes for image at index 455:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.91  37.    17.   474.   753.  ]
#  [  2.     0.7  434.    64.   826.   748.  ]]
#
#
# Image: test/b5b95fce8631ff1c
# Predicted boxes for image at index 456:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.83 105.    41.   682.   929.  ]]
#
#
# Image: test/0b84a70c2ac0c874
# Predicted boxes for image at index 457:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/59440580cb80e791
# Predicted boxes for image at index 458:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.91 709.   203.   960.   647.  ]
#  [  1.     0.88 304.    91.   738.   647.  ]]
#
#
# Image: test/013dbf33cfba6453
# Predicted boxes for image at index 459:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.     0.8   56.   148.   651.  1015. ]]
#
#
# Image: test/cb7ef4061559070c
# Predicted boxes for image at index 460:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.82 475.   147.   641.   638.  ]
#  [  1.     0.6  480.    99.   569.   401.  ]
#  [  1.     0.51 341.    28.   502.   465.  ]]
#
#
# Image: test/0038b12aeccdcb7e
# Predicted boxes for image at index 461:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.55 352.   392.   589.   591.  ]]
#
#
# Image: test/1a2d77e59fcd210a
# Predicted boxes for image at index 462:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.53 539.    47.   779.   556.  ]]
#
#
# Image: test/07afbe28e286087e
# Predicted boxes for image at index 463:
#    class   conf xmin   ymin   xmax   ymax
# [[   3.      0.89    4.      9.   1015.    769.  ]]
#
#
# Image: test/9b802f58f23029f4
# Predicted boxes for image at index 464:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.92 -15.    -5.   804.   665.  ]]
#
#
# Image: test/e2b2bb769a02252f
# Predicted boxes for image at index 465:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.91  111.    146.    816.   1010.  ]
#  [   2.      0.5   419.    168.    872.    965.  ]]
#
#
# Image: test/6eb2c1c2e058fd66
# Predicted boxes for image at index 466:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.79 -14.   145.   630.   957.  ]]
#
#
# Image: test/6894e498b8e1051a
# Predicted boxes for image at index 467:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.96 154.   135.   511.   927.  ]]
#
#
# Image: test/7b4d8bac80d7fc1b
# Predicted boxes for image at index 468:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.92  15.    44.   153.   391.  ]
#  [  1.     0.57 698.    46.   736.   121.  ]]
#
#
# Image: test/0d395241868daaca
# Predicted boxes for image at index 469:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.75  81.    19.   529.   820.  ]]
#
#
# Image: test/2d778619f12c8aa1
# Predicted boxes for image at index 470:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.64 173.    86.   473.   883.  ]]
#
#
# Image: test/909fdca8db79d695
# Predicted boxes for image at index 471:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.59 283.    15.   938.   678.  ]
#  [  4.     0.55 213.    17.   877.   651.  ]]
#
#
# Image: test/a2c1d4542901af59
# Predicted boxes for image at index 472:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.94 683.    65.   882.   468.  ]
#  [  1.     0.89 347.    14.   610.   500.  ]
#  [  1.     0.62  23.    11.   222.   470.  ]]
#
#
# Image: test/f8e16c37d86cf7f1
# Predicted boxes for image at index 473:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.85 482.   202.   675.   603.  ]]
#
#
# Image: test/b038ae3586b13150
# Predicted boxes for image at index 474:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.81 795.    97.   893.   218.  ]
#  [  3.     0.74 -12.    79.   458.   727.  ]]
#
#
# Image: test/add49d324b6c6519
# Predicted boxes for image at index 475:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.62 584.    71.   819.   425.  ]
#  [  3.     0.91 223.   208.   474.   549.  ]
#  [  3.     0.88 174.   216.   311.   577.  ]]
#
#
# Image: test/b93910f29c88135c
# Predicted boxes for image at index 476:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98 616.    45.   923.   648.  ]
#  [  2.     0.81 436.   191.   665.   642.  ]]
#
#
# Image: test/b920e2c13ee0a44a
# Predicted boxes for image at index 477:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.57 162.   428.   253.   659.  ]
#  [  1.     0.51 715.     9.   821.   266.  ]
#  [  2.     0.51 507.   485.   609.   687.  ]]
#
#
# Image: test/70d82a0855d7db1e
# Predicted boxes for image at index 478:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.89 737.   285.   863.   553.  ]]
#
#
# Image: test/d28e65cf1318a74f
# Predicted boxes for image at index 479:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98  24.    39.   766.   760.  ]]
#
#
# Image: test/bb8a221ad746a88d
# Predicted boxes for image at index 480:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.61  34.    10.   939.   705.  ]]
#
#
# Image: test/0da08033b803bce3
# Predicted boxes for image at index 481:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.52 151.   106.   757.   704.  ]
#  [  4.     0.65 108.   334.   660.   725.  ]]
#
#
# Image: test/75d2aff147a3d9b2
# Predicted boxes for image at index 482:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/2714e794df83fdc7
# Predicted boxes for image at index 483:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.81 579.    42.   978.   743.  ]]
#
#
# Image: test/9f5ce702bc30f4bb
# Predicted boxes for image at index 484:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.76 -12.    10.   546.   525.  ]
#  [  2.     0.68 131.    24.   842.   745.  ]
#  [  3.     0.6   74.     1.   193.   116.  ]]
#
#
# Image: test/a0646ac59cc509d3
# Predicted boxes for image at index 485:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.77  15.   -42.   521.   744.  ]
#  [  4.     0.76 383.    -8.   975.   728.  ]]
#
#
# Image: test/1bb650046adf915c
# Predicted boxes for image at index 486:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.67 223.   183.   644.   972.  ]]
#
#
# Image: test/2a948f136be07717
# Predicted boxes for image at index 487:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.54 360.   138.   625.   711.  ]
#  [  2.     0.87 540.   171.   976.   726.  ]
#  [  2.     0.7    1.   131.   443.   761.  ]
#  [  2.     0.65 353.   121.   611.   695.  ]]
#
#
# Image: test/04f871899d640c8b
# Predicted boxes for image at index 488:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.61 131.    38.   620.   998.  ]
#  [  4.     0.59 110.    15.   585.   965.  ]]
#
#
# Image: test/78efeeaaa1f0065a
# Predicted boxes for image at index 489:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.99 302.   129.   613.   864.  ]
#  [  3.     0.97  43.   146.   342.   851.  ]]
#
#
# Image: test/f40d7cd71333a71c
# Predicted boxes for image at index 490:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.61 233.    94.   605.   763.  ]]
#
#
# Image: test/3a3255202e45c0ff
# Predicted boxes for image at index 491:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.73 403.   -10.   900.   638.  ]
#  [  2.     0.55 587.     4.   690.   225.  ]
#  [  4.     0.81  57.   -13.   469.   702.  ]]
#
#
# Image: test/8c8437145fedb582
# Predicted boxes for image at index 492:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.57 -16.    27.   778.   986.  ]]
#
#
# Image: test/430294ae5f3282de
# Predicted boxes for image at index 493:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.    0.6  18.   22.  747.  723. ]]
#
#
# Image: test/d100c733d7af6ce3
# Predicted boxes for image at index 494:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.84 108.    75.   825.   679.  ]]
#
#
# Image: test/e7c1cc990b7688bb
# Predicted boxes for image at index 495:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.99    8.     24.    669.   1007.  ]]
#
#
# Image: test/aa5b2f096711b5ab
# Predicted boxes for image at index 496:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.89  74.   198.   200.   498.  ]
#  [  3.     0.72 768.   356.   887.   576.  ]]
#
#
# Image: test/6f0f875ad1cbf880
# Predicted boxes for image at index 497:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.78 756.   -18.   946.   489.  ]
#  [  1.     0.66 511.    13.   628.   174.  ]]
#
#
# Image: test/6015ddd1b7e7fd2a
# Predicted boxes for image at index 498:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.    0.8 312.  -21.  588.  440. ]]
#
#
# Image: test/4b1c82abd1b42f0f
# Predicted boxes for image at index 499:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.86  60.   322.   205.   679.  ]]
#
#
# Image: test/5dbfb079d8db2c72
# Predicted boxes for image at index 500:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.62 783.   219.   949.   648.  ]
#  [  3.     0.73 407.   287.   522.   626.  ]]
#
#
# Image: test/b3a94b0a61eb8e96
# Predicted boxes for image at index 501:
#    class   conf xmin   ymin   xmax   ymax
# [[   3.      0.63  777.    385.   1009.    554.  ]
#  [   4.      0.84  202.     82.    509.    522.  ]
#  [   4.      0.59  575.    142.    945.    534.  ]]
#
#
# Image: test/80f0f6792b623c85
# Predicted boxes for image at index 502:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.     0.9   11.    60.  1005.  1012. ]]
#
#
# Image: test/055aa9c8e194b5a4
# Predicted boxes for image at index 503:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.71  22.    29.   663.   890.  ]]
#
#
# Image: test/9dcd00b462e6bc66
# Predicted boxes for image at index 504:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.94  70.    62.   905.   681.  ]]
#
#
# Image: test/33b065ff034fd571
# Predicted boxes for image at index 505:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.96 144.   420.   390.   901.  ]
#  [  4.     0.66 537.   506.   725.   943.  ]]
#
#
# Image: test/f0181fa55953892d
# Predicted boxes for image at index 506:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.87 538.   128.   773.   642.  ]
#  [  1.     0.72 461.   123.   491.   219.  ]
#  [  1.     0.72 433.   124.   463.   219.  ]
#  [  1.     0.65 381.   127.   410.   222.  ]
#  [  1.     0.63 410.   124.   438.   220.  ]
#  [  1.     0.63 324.   127.   353.   225.  ]
#  [  1.     0.62 353.   128.   383.   224.  ]
#  [  1.     0.59 485.   123.   516.   219.  ]
#  [  1.     0.59 888.   127.   924.   215.  ]
#  [  1.     0.58 862.   128.   898.   216.  ]
#  [  1.     0.57 273.   124.   305.   233.  ]
#  [  1.     0.57 914.   127.   951.   215.  ]
#  [  1.     0.55 300.   126.   329.   227.  ]
#  [  1.     0.55 836.   130.   871.   217.  ]
#  [  1.     0.53 810.   132.   842.   218.  ]
#  [  1.     0.52 110.   128.   144.   224.  ]
#  [  1.     0.52  46.   125.    90.   221.  ]
#  [  1.     0.52  80.   128.   119.   222.  ]
#  [  1.     0.52 136.   127.   170.   225.  ]
#  [  1.     0.5  162.   127.   196.   228.  ]
#  [  1.     0.5  243.   123.   274.   235.  ]]
#
#
# Image: test/4e030db7e2039d02
# Predicted boxes for image at index 507:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.85 372.    17.   776.   745.  ]]
#
#
# Image: test/5a4fc14161a53bb4
# Predicted boxes for image at index 508:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.52 478.   196.   529.   330.  ]
#  [  4.     0.89 554.   177.   787.   608.  ]
#  [  4.     0.76 126.   206.   483.   688.  ]
#  [  4.     0.66 704.   107.   965.   694.  ]]
#
#
# Image: test/f8117c37bd1081ad
# Predicted boxes for image at index 509:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.64   -7.     23.    708.   1010.  ]
#  [   4.      0.52    2.     16.    744.    984.  ]]
#
#
# Image: test/a534ac6cddacaf4b
# Predicted boxes for image at index 510:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.66 680.    99.   881.   648.  ]]
#
#
# Image: test/50175becd2637361
# Predicted boxes for image at index 511:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.93 832.   259.   931.   518.  ]
#  [  1.     0.77 904.   261.   995.   520.  ]
#  [  3.     0.77  38.   330.   198.   605.  ]]
#
#
# Image: test/54f55316141b3f13
# Predicted boxes for image at index 512:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.86  -10.     33.    705.   1019.  ]]
#
#
# Image: test/c4c12d3770377354
# Predicted boxes for image at index 513:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98 344.   294.   490.   387.  ]
#  [  1.     0.57 158.   272.   293.   398.  ]
#  [  2.     0.63 567.   320.   653.   384.  ]
#  [  4.     0.77 748.   285.   885.   372.  ]]
#
#
# Image: test/4bfa10cdb11c135c
# Predicted boxes for image at index 514:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.93 237.   178.   489.   900.  ]]
#
#
# Image: test/ca41e3f9a6b5233c
# Predicted boxes for image at index 515:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.92  62.    12.   302.   628.  ]
#  [  4.     0.68 394.   154.   571.   637.  ]
#  [  4.     0.54 238.   154.   396.   629.  ]]
#
#
# Image: test/3e05ba47acec4729
# Predicted boxes for image at index 516:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.   1. 149.   6. 964. 687.]]
#
#
# Image: test/839bcdd34c9ed767
# Predicted boxes for image at index 517:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.87 442.   114.   818.   648.  ]
#  [  1.     0.66 150.   161.   253.   394.  ]
#  [  1.     0.55   3.    94.   139.   645.  ]
#  [  2.     0.92 250.   154.   489.   642.  ]
#  [  2.     0.64 515.   162.   598.   349.  ]
#  [  2.     0.5  820.   142.   959.   630.  ]]
#
#
# Image: test/2da2c22f1bd3d367
# Predicted boxes for image at index 518:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.96 300.   194.   557.   665.  ]]
#
#
# Image: test/b656d547bd619b38
# Predicted boxes for image at index 519:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/9c19eb0c20e1b770
# Predicted boxes for image at index 520:
#    class   conf xmin   ymin   xmax   ymax
# ...
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.95   70.    113.    612.   1026.  ]]
#
#
# Image: test/8ccd75c7bd8a4287
# Predicted boxes for image at index 925:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.93  26.     7.   298.   463.  ]
#  [  1.     0.59 585.    20.   858.   573.  ]
#  [  3.     0.62 517.    49.   747.   568.  ]]
#
#
# Image: test/d85a059d048a8aa9
# Predicted boxes for image at index 926:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.58 574.   -11.   844.   705.  ]
#  [  2.     0.53  41.     2.   476.   754.  ]
#  [  4.     0.57  22.   -42.   438.   750.  ]]
#
#
# Image: test/09430ad6e959b3e0
# Predicted boxes for image at index 927:
#    class   conf xmin   ymin   xmax   ymax
# [[   4.      0.88  121.     32.    618.   1020.  ]]
#
#
# Image: test/8778a3c219033997
# Predicted boxes for image at index 928:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/11c148679e6d9ac5
# Predicted boxes for image at index 929:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.66 361.   264.   756.   515.  ]
#  [  4.     0.54 528.   299.   780.   531.  ]]
#
#
# Image: test/bd4324ad1bb02191
# Predicted boxes for image at index 930:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99  93.    -0.   697.   992.  ]]
#
#
# Image: test/f343cee1cb3a3826
# Predicted boxes for image at index 931:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/63e77a7cc34a58f8
# Predicted boxes for image at index 932:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.66 410.    98.   913.   538.  ]
#  [  3.     0.92 382.   189.   850.   551.  ]]
#
#
# Image: test/e92148cb276bde7b
# Predicted boxes for image at index 933:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.66 558.    -2.   748.   171.  ]
#  [  1.     0.57  10.   148.    70.   295.  ]]
#
#
# Image: test/ed199278b9e87476
# Predicted boxes for image at index 934:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.91  85.   152.   547.   859.  ]
#  [  3.     0.52 495.   291.   606.   518.  ]]
#
#
# Image: test/e45b74e1069ec7c6
# Predicted boxes for image at index 935:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.83  99.    97.   543.   970.  ]]
#
#
# Image: test/3c8116244f68283a
# Predicted boxes for image at index 936:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.92  27.    26.   306.   875.  ]]
#
#
# Image: test/a29ce0b363f440f5
# Predicted boxes for image at index 937:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.81 506.   187.   795.   641.  ]]
#
#
# Image: test/07d245a0f2de1b9a
# Predicted boxes for image at index 938:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.68  -3.    -7.   288.   737.  ]]
#
#
# Image: test/e6c9c960350d2839
# Predicted boxes for image at index 939:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.99   4.    31.   623.   931.  ]]
#
#
# Image: test/77610c816c6f34a7
# Predicted boxes for image at index 940:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 214.     1.   473.   302.  ]
#  [  2.     0.95 418.    12.   709.   355.  ]]
#
#
# Image: test/fc38c95b141f33d1
# Predicted boxes for image at index 941:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.83  757.     85.    955.    579.  ]
#  [   1.      0.69  384.     20.    962.    884.  ]
#  [   2.      0.75    1.    -25.    555.   1026.  ]]
#
#
# Image: test/ab4b7e39e4b20f99
# Predicted boxes for image at index 942:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.67   7.    77.   687.   911.  ]]
#
#
# Image: test/dc5726d1977eb07b
# Predicted boxes for image at index 943:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.82  11.   131.   982.   933.  ]]
#
#
# Image: test/1b32e788da559845
# Predicted boxes for image at index 944:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.93 256.   215.   453.   622.  ]
#  [  3.     0.58 593.   224.   762.   630.  ]
#  [  3.     0.55 410.   246.   567.   646.  ]
#  [  4.     0.64  45.   241.   210.   636.  ]]
#
#
# Image: test/c3e41ef3b010f063
# Predicted boxes for image at index 945:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.65  34.     1.   708.   671.  ]]
#
#
# Image: test/8c6ea225e96faf86
# Predicted boxes for image at index 946:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.91  153.    225.    476.    641.  ]
#  [   1.      0.85  363.    230.    597.    614.  ]
#  [   1.      0.53  421.    103.   1011.    671.  ]
#  [   3.      0.63  400.     74.    966.    660.  ]]
#
#
# Image: test/0c07862c8ac8835f
# Predicted boxes for image at index 947:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/b6fe7a40d24be356
# Predicted boxes for image at index 948:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 225.    80.   789.   744.  ]
#  [  1.     0.89  -2.    78.   398.   751.  ]
#  [  1.     0.67 547.    55.   963.   783.  ]]
#
#
# Image: test/6b170f280fa50242
# Predicted boxes for image at index 949:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/fbcb636a53e3fa28
# Predicted boxes for image at index 950:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.58   0.    30.   176.   480.  ]
#  [  1.     0.53 437.    38.   619.   455.  ]
#  [  2.     0.52 240.   124.   444.   508.  ]
#  [  3.     0.98 409.   158.   544.   422.  ]
#  [  3.     0.53 435.    55.   620.   442.  ]]
#
#
# Image: test/cc7664bebea6e7ab
# Predicted boxes for image at index 951:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.76 579.   252.   770.   615.  ]]
#
#
# Image: test/361c18bd16ea0a78
# Predicted boxes for image at index 952:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.79 421.   264.   833.   685.  ]]
#
#
# Image: test/3f90d8155753ff39
# Predicted boxes for image at index 953:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99   5.    92.   515.   737.  ]
#  [  2.     0.62 385.    57.   923.   746.  ]]
#
#
# Image: test/5513de3c10ae65ae
# Predicted boxes for image at index 954:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.78 483.   224.   661.   697.  ]]
#
#
# Image: test/8d68cb9d22cad12f
# Predicted boxes for image at index 955:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.95   77.     87.    491.   1025.  ]]
#
#
# Image: test/74256d0234e59145
# Predicted boxes for image at index 956:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.53 756.   179.   854.   427.  ]
#  [  4.     0.62  85.   319.   162.   421.  ]]
#
#
# Image: test/c64845b617bd7f17
# Predicted boxes for image at index 957:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.84 271.   158.   656.   603.  ]]
#
#
# Image: test/d02cbd6e02d40009
# Predicted boxes for image at index 958:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.5    40.     63.    532.   1003.  ]
#  [   4.      0.61   33.     65.    525.   1027.  ]]
#
#
# Image: test/32254deda1fa8568
# Predicted boxes for image at index 959:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.99 446.   183.   683.   582.  ]]
#
#
# Image: test/3fec48b329b26908
# Predicted boxes for image at index 960:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.92  46.    81.   374.   897.  ]
#  [  1.     0.91 356.    68.   667.   911.  ]]
#
#
# Image: test/65ec1cde46fd03d9
# Predicted boxes for image at index 961:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.93 144.   292.   423.   589.  ]]
#
#
# Image: test/5c955e3a7555aa23
# Predicted boxes for image at index 962:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.7  140.    74.   410.   702.  ]
#  [  4.     0.95 553.    91.   785.   588.  ]]
#
#
# Image: test/e69d5fd0fdf74fbc
# Predicted boxes for image at index 963:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/9c1b947e76e88e4c
# Predicted boxes for image at index 964:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.96 700.   265.   959.   726.  ]
#  [  1.     0.92 173.   155.   485.   736.  ]
#  [  1.     0.9  906.   200.   967.   316.  ]
#  [  1.     0.69 840.   205.   907.   302.  ]
#  [  2.     0.78 457.    90.   726.   735.  ]]
#
#
# Image: test/12ab073ecf261b48
# Predicted boxes for image at index 965:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.84 651.   321.   773.   676.  ]
#  [  3.     0.83 776.   316.   915.   679.  ]
#  [  3.     0.61 172.   328.   296.   676.  ]
#  [  3.     0.52 547.   328.   665.   680.  ]
#  [  3.     0.5  294.   316.   415.   670.  ]]
#
#
# Image: test/c710e24b4ab73c24
# Predicted boxes for image at index 966:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.83 195.   263.   518.   926.  ]
#  [  1.     0.82 404.   264.   626.   671.  ]]
#
#
# Image: test/af0cad04f05549b3
# Predicted boxes for image at index 967:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.95  192.    155.    726.    761.  ]
#  [   2.      0.53  240.    489.    366.    687.  ]
#  [   3.      0.93   60.    495.    240.    710.  ]
#  [   3.      0.91  233.    364.    330.    478.  ]
#  [   3.      0.8   906.    342.   1004.    683.  ]
#  [   3.      0.79  831.    361.    936.    681.  ]
#  [   3.      0.74  659.    417.    785.    689.  ]
#  [   3.      0.69  229.    480.    363.    683.  ]
#  [   3.      0.68   -2.    421.     77.    576.  ]
#  [   3.      0.62    9.    502.    159.    720.  ]
#  [   3.      0.54  728.    401.    849.    681.  ]]
#
#
# Image: test/8f6259ce5760ffcc
# Predicted boxes for image at index 968:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.     0.7  -24.    10.  1007.   948. ]]
#
#
# Image: test/2a36113061b4e6eb
# Predicted boxes for image at index 969:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.79 810.   259.   902.   368.  ]
#  [  3.     0.55 447.   277.   559.   585.  ]]
#
#
# Image: test/97af041a17f4a473
# Predicted boxes for image at index 970:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.85 104.   123.   384.   648.  ]
#  [  4.     0.54  13.   255.   204.   639.  ]]
#
#
# Image: test/cd1339c041d5fc9d
# Predicted boxes for image at index 971:
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.83 334.   313.   460.   457.  ]]
#
#
# Image: test/360a7e322ce0bdab
# Predicted boxes for image at index 972:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 309.    77.   787.   542.  ]]
#
#
# Image: test/5a7181ca067d16fe
# Predicted boxes for image at index 973:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.89 545.    88.   847.   658.  ]
#  [  4.     0.73 292.    92.   476.   363.  ]
#  [  4.     0.51 566.   103.   686.   330.  ]]
#
#
# Image: test/0d4becbb921d522c
# Predicted boxes for image at index 974:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.    0.9 275.  506.  472.  789. ]]
#
#
# Image: test/3ecc8dd591d2496d
# Predicted boxes for image at index 975:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 723.   235.   859.   502.  ]
#  [  1.     0.95 703.    51.   778.   156.  ]
#  [  1.     0.93 868.   313.   978.   514.  ]
#  [  1.     0.66 440.   295.   566.   492.  ]
#  [  1.     0.57 140.    33.   323.   531.  ]
#  [  1.     0.56 562.    18.   621.   139.  ]
#  [  1.     0.51 474.   153.   762.   603.  ]
#  [  2.     0.58 261.    96.   518.   600.  ]]
#
#
# Image: test/7bf9c82292fa5f93
# Predicted boxes for image at index 976:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.67    3.     17.    659.   1017.  ]]
#
#
# Image: test/0b35fc31c3c6b33f
# Predicted boxes for image at index 977:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.89 651.   111.   841.   630.  ]]
#
#
# Image: test/f85e447b48ecc509
# Predicted boxes for image at index 978:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.69 205.   265.   429.   540.  ]
#  [  3.     0.93 418.   469.   682.   728.  ]
#  [  3.     0.89 108.   471.   397.   718.  ]
#  [  3.     0.88 295.   473.   469.   729.  ]
#  [  3.     0.87 695.   451.   878.   721.  ]
#  [  3.     0.85 548.   471.   763.   730.  ]
#  [  3.     0.55 516.   258.   743.   548.  ]
#  [  4.     0.64 446.    98.   599.   385.  ]]
#
#
# Image: test/2807437d7a3120c6
# Predicted boxes for image at index 979:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.58   53.      5.    577.   1021.  ]]
#
#
# Image: test/d5b0848802bdc67b
# Predicted boxes for image at index 980:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.73 284.   164.   406.   359.  ]
#  [  3.     0.67 530.   313.   621.   527.  ]]
#
#
# Image: test/fa93a27e2acd6a3e
# Predicted boxes for image at index 981:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.94 758.   334.   962.   637.  ]
#  [  1.     0.91 538.   371.   841.   646.  ]
#  [  1.     0.8  148.   413.   383.   679.  ]
#  [  1.     0.74   5.   430.   218.   674.  ]
#  [  1.     0.56 284.    57.   750.   681.  ]]
#
#
# Image: test/1fb794ab03ff15fb
# Predicted boxes for image at index 982:
#    class   conf xmin   ymin   xmax   ymax
# [[   3.      0.63    7.     10.    663.   1031.  ]]
#
#
# Image: test/158afe68201437a6
# Predicted boxes for image at index 983:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.98 377.   160.   641.   737.  ]
#  [  1.     0.97  96.    69.   424.   745.  ]
#  [  1.     0.55  -2.   148.   139.   576.  ]]
#
#
# Image: test/c1b6f9456508fe17
# Predicted boxes for image at index 984:
#    class   conf xmin   ymin   xmax   ymax
# []
#
#
# Image: test/fd2937b2cd608754
# Predicted boxes for image at index 985:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.93 207.    64.   489.   503.  ]
#  [  1.     0.86 427.    72.   777.   535.  ]
#  [  1.     0.71 681.   107.   963.   541.  ]
#  [  1.     0.68  11.    32.   343.   614.  ]]
#
#
# Image: test/d9c82f2be23ae7b8
# Predicted boxes for image at index 986:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.62   36.    324.    378.    732.  ]
#  [   3.      0.74  633.    225.    833.    624.  ]
#  [   3.      0.63  458.    188.    677.    742.  ]
#  [   3.      0.56   35.    322.    358.    742.  ]
#  [   4.      0.72  867.    316.   1005.    595.  ]]
#
#
# Image: test/5f0e980ee13e099f
# Predicted boxes for image at index 987:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.99   23.     53.    839.   1024.  ]]
#
#
# Image: test/bebc876ff1e883f2
# Predicted boxes for image at index 988:
#    class   conf xmin   ymin   xmax   ymax
# [[   2.      0.74   51.     55.    996.   1015.  ]]
#
#
# Image: test/4409d6a5cbc5b110
# Predicted boxes for image at index 989:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.62 230.   473.   492.   789.  ]]
#
#
# Image: test/d10b41775cd58955
# Predicted boxes for image at index 990:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.     0.5   33.    94.   202.   538. ]
#  [   2.     0.7  953.   305.  1010.   432. ]]
#
#
# Image: test/c50fd9dd89f7b200
# Predicted boxes for image at index 991:
#    class   conf xmin   ymin   xmax   ymax
# [[  2.     0.84  68.    52.   758.   760.  ]]
#
#
# Image: test/890d41fde2503380
# Predicted boxes for image at index 992:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.83  79.   113.   219.   591.  ]
#  [  1.     0.77  -1.    28.   127.   691.  ]
#  [  2.     0.93 170.   -24.   466.   974.  ]
#  [  2.     0.63 464.   131.   641.   478.  ]]
#
#
# Image: test/5305a594e5f192ae
# Predicted boxes for image at index 993:
#    class   conf xmin   ymin   xmax   ymax
# [[  4.     0.82 -20.   -31.   506.   943.  ]
#  [  4.     0.66 387.   -17.   978.   653.  ]]
#
#
# Image: test/c511f739667a9b9a
# Predicted boxes for image at index 994:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.84 467.   157.   858.   594.  ]]
#
#
# Image: test/d8d3b805f9eb801b
# Predicted boxes for image at index 995:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.74 835.   182.   874.   294.  ]]
#
#
# Image: test/7c0780f63122581e
# Predicted boxes for image at index 996:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99   1.   133.   349.   437.  ]
#  [  1.     0.93 707.   140.   956.   422.  ]
#  [  1.     0.91 367.   133.   811.   437.  ]]
#
#
# Image: test/05eea091c2b4cbaf
# Predicted boxes for image at index 997:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99 336.   206.   559.   647.  ]
#  [  1.     0.84 309.    73.   483.   248.  ]]
#
#
# Image: test/3a22e3fceeffc968
# Predicted boxes for image at index 998:
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.88 324.   246.   707.   901.  ]]
#
#
# Image: test/98f9bd50770d9d3d
# Predicted boxes for image at index 999:
#    class   conf xmin   ymin   xmax   ymax
# [[   1.      0.82  406.    158.    693.   1000.  ]
#  [   1.      0.75   18.    104.    272.    987.  ]
#  [   1.      0.69   49.    -18.    274.    568.  ]]

# %% [markdown]
# Finally, let's draw the predicted boxes onto the image. Each predicted box says its confidence next to the category name. The ground truth boxes are also drawn onto the image in green for comparison.

# %%
import os

# output to text files for mAP calculation

print(len(batch_original_labels))
print(len(y_pred_decoded_inv))

classes = ['background','Man', 'Woman' , 'Boy' , 'Girl']

if not os.path.exists("mep/input-balanced-epoch-"+str(final_epoch)+"/ground-truth/"):
    os.makedirs("mep/input-balanced-epoch-"+str(final_epoch)+"/ground-truth/")
if not os.path.exists("mep/input-balanced-epoch-"+str(final_epoch)+"/detection-results/"):
    os.makedirs("mep/input-balanced-epoch-"+str(final_epoch)+"/detection-results/")


for i in range(len(batch_filenames)):
  fileName = batch_filenames[i]
  fileID = str(fileName[fileName.index("/")+1:])
  if i % 100 == 0:
    print(i)
  
  with open("mep/input-balanced-epoch-"+str(final_epoch)+"/ground-truth/"+fileID+".txt", "w+") as f:
    #print(f)
    for box in batch_original_labels[i]:
      f.write( str(classes[int(box[0])]) + " " + str(box[1]) + " " + str(box[2]) + " " + str(box[3]) + " " + str(box[4]) + "\n")

  with open("mep/input-balanced-epoch-"+str(final_epoch)+"/detection-results/"+fileID+".txt", "w+") as f:
    #print(f)
    for box in y_pred_decoded_inv[i]:
      f.write( str(classes[int(box[0])]) + " " + str(box[1]) + " " + str(int(box[2])) + " " + str(int(box[3])) + " " + str(int(box[4])) + " " + str(int(box[5])) + "\n")
# Out:
# 1000
# 1000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
# %cd /content/drive/My Drive/ssd_keras/map/mAP

# !ls

#!git clone https://github.com/Cartucho/mAP.git

# %%
# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
#classes = ['background',
           #'aeroplane', 'bicycle', 'bird', 'boat',
           #'bottle', 'bus', 'car', 'cat',
           #'chair', 'cow', 'diningtable', 'dog',
           #'horse', 'motorbike', 'person', 'pottedplant',
           #'sheep', 'sofa', 'train', 'tvmonitor']

classes = ['background','Man', 'Woman' , 'Boy' , 'Girl']

#i = 568
#i = 358
i = 212

plt.figure(figsize=(20,12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    #current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    #current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='black', bbox={'facecolor':color, 'alpha':1.0})
