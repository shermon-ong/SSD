# %%
# [OKH] this is to mount Google Drive and change to the directory containing the mAP evaluator

from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/ssd_keras/mAP
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/ssd_keras/mAP

# %%
# [OKH]

# !python main.py
# Out:
# 0.05% = Boy AP
# 0.14% = Girl AP
# 0.11% = Man AP
# 0.12% = Woman AP
# mAP = 0.10%
# <Figure size 640x480 with 1 Axes>
